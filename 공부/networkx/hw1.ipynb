# %%
import networkx as nx
import pandas as pd

# %%
import wikipediaapi
wiki=wikipediaapi.Wikipedia('ko')
page_py = wiki.page('스모그')
print("Page - Exists: %s" % page_py.exists())
# Out:
# Page - Exists: True

# %%
wiki1 = wikipediaapi.Wikipedia(language='ko', extract_format=wikipediaapi.ExtractFormat.WIKI) 
p_wiki1 = wiki1.page("미세먼지") 
print(p_wiki1.text)
# Out:
# 미세먼지(微細-, 영어: particulate matter, PM, suspended particulate matter, SPM, atmospheric aerosol particles, atmospheric particulate matter) 또는 분진(粉塵)은 눈에 보이지 않을 정도로 입자가 작은 먼지이다. 아황산가스, 질소 산화물, 납, 오존, 일산화 탄소 등을 포함하는 대기오염 물질로 자동차, 공장, 조리 과정 등에서 발생하여 대기 중 장기간 떠다니는 입경(입자의 지름) 10μm 이하의 미세한 먼지이며, PM10이라고도 한다. 입자가 2.5μm 이하인 경우는 PM 2.5라고 쓰며 '초미세먼지' 또는 '극미세먼지' 라고도 부른다. 학술적으로는 에어로졸(aerosol)이라고 부른다. 미세먼지(fine particles)는 부유분진(Suspended particles), 입자상물질(Particulate matter) 등으로도 불리며 명칭에 따라 약간씩 다른 의미를 가지고 있다. 입자상물질은 지름이 100μm에서 10나노미터 정도이며, 이보다 지름이 크면 중력으로 인해 대기중 체류시간이 아주 짧다.
#
# 개요
# 인체에 큰 영향을 미치는 물질이다. 1948년 미국 펜실베이니아주 도노라에서 20명이 사망한 대기오염사고, 1952년 약 4,100명의 사망자를 발생시킨 런던스모그는 미세먼지가 인체에 어떤 영향을 미치는지 보여 주는 대표적인 사례이다. 그 이후로 미세먼지가 인체에 미치는 영향에 대한 다양한 역학조사가 실시되었고, 특히 10μm 이하의 미세먼지 입자(PM10)가 취약집단의 질병발생률과 사망률을 높이는 등 인체에 해로운 영향을 미칠 가능성이 높다는 것이 밝혀졌다. 이후 각 국에서 대기오염대책이 마련되었으며, 미세먼지가 인체와 환경에 미치는 해로운 영향을 줄이기 위해 대기오염기준도 마련하였다. 미세먼지는 입자의 크기에 따라 50µm 이하인 총먼지(TPS, TOTAL SUSPENDED PARTICLES)와 입자 크기가 매우 작은 미세먼지로 구분한다. 미세먼지는 지름이 10µm 보다 작은 미세먼지(PM10)와 지름이 2.5µm보다 작은 미세먼지(PM2.5)로 나뉜다.
# 공기 속에 입자상물질(고체나 액체상태)이 부유하고 있는 상태를 일반적으로 에어로졸(Aerosol)이라 한다. 통상적으로 먼지라 말하고 있다.
#
# 먼지의 입도(粒度)범위는 0.001～1000μm이지만 70μm이상의 먼지는 발생 즉시 침강하므로 일반적으로 70μm 미만의 총먼지(TSP, Total Suspended Particle)라 한다.
# 0.1μm 이하의 먼지입경을 초범위(ultra range)라 하며, 대부분의 먼지는 0.1～10μm 사이에 분포하게 된다. 0.1～1μm 범위의 입자는 입경분포의 특성상 침강이나 응집이 쉽지 않기 때문에 대기 중에 체류시간이 길고 폐포(肺胞)에 침투가 가장 용이하다.
# 0.5μm 크기의 입자는 빛의 산란효과가 가장 커서 시정감소 등의 원인이 되기도 한다.
#
# 먼지들의 분류
# PM-10 (10μm 미만 입자)
# 입자의 크기가 10μm 미만인 먼지를 말한다. 국가에서 환경기준으로 연평균 50㎍/㎥ , 24시간 평균 100㎍/㎥를 기준으로 하고 있다. 인체의 폐포까지 침투하여 각종 호흡기 질환의 직접적인 원인이 되며, 인체의 면역 기능을 악화시킨다. 세계보건기구(WHO) 가이드라인으로는 연평균 20㎍/㎥, 24시간 평균 50㎍/㎥으로 설정되어있으며, 개발도상국의 경우 연평균 70㎍/㎥ 정도라고 한다.
#
# PM-2.5 (2.5μm 미만 입자)
# 입자의 크기가 2.5μm 미만인 먼지를 말한다. 이것을 초미세먼지라고 한다.
# 입자의 크기가 작을수록 건강에 미치는 영향이 크다는 결과에 따라 선진국에서 미세입자에 대한 기준을 90년대 후반부터 도입하기 시작했다.
# 대한민국은 연평균 15㎍/㎥, 24시간 평균 35㎍/㎥의 기준을 발표하였으며, 미국은 연평균 15㎍/㎥, 24시간 평균 35㎍/㎥의 기준을 설정하였다. 세계보건기구(WHO) 가이드라인으로는 연평균 10㎍/㎥, 24시간 평균 25㎍/㎥으로 설정되어있다.
#
# TSP (Total suspended Particles, 총 부유 입자)
# 총부유분진 또는 총부유입자상 물질 또는 총입자상 물질이라고 하며, 통상적으로 50μm 이하의 모든 부유 먼지를 말한다. 입자의 크기가 10μm이상인 경우에는 도시미관에 영향을 미치긴 하지만 인체의 건강에는 영향이 적기 때문에 90년대 후반 TSP 에서 PM-10으로 환경기준을 변경하였다.
#
# 발생 원인
# 미세먼지의 배출원인은 인위적인 발생과 자연적인 발생으로 구분된다. 인위적인 발생의 원인은 중국발 미세먼지, 공장에서 나오는 매연 쓰레기소각, 항만지역, 가정에서 생선이나 그 외의 것을 구울 때 등이 있다. 자연발생 원인은 모래바람의 먼지, 화산재, 산불이 일 때 발생하는 먼지 등이다. 해염입자 또한 바다 가까이에 위치한 지역에는 많은 영향을 미친다.
#
# 발생 국가
# 중국과 한국중국의 경우 세계에서 화석 연료를 가장 많이 소비시키는 나라로 손을 꼽히고 있으며 베이징시, 톈진시, 칭다오시 등과 같은 동부 지역과 고비 사막과 인접해 있는 곳도 역시 미세먼지의 주범이 되는 등 아시아 최대 미세먼지 발생 원인 제공국으로 손을 꼽히고 있다. 다만 미세먼지는 주로 건기인 겨울에 가장 많이 발생시켜서 한반도는 북한 전 지역과 대한민국의 새만금 이북 지역 중 양간지풍에 영향을 받는 강원도의 영동 지방과 경상북도 북부 동해안, 울릉도, 독도를 제외한 중부 전 지역과 남부 일부 지역에만 심하게 발생된다. 다만 북한의 경우 함경북도, 라선특별시, 함경남도 동북부 일부 지역 등 베이징과 많이 떨어진 지역은 덜 받는 곳으로 손을 꼽힌다.
#
# 일본일본의 경우 드물게도 미세먼지가 규슈, 이키섬, 쓰시마섬 등지에서도 간헐적으로 발생되는 경우도 있는 것으로 보인다. 우리나라는 중국에서 미세먼지로 피해를 받는다
#
# 러시아러시아는 대체적으로 미세먼지 발생량이 적게 나오지만 지역에 따라 편차가 다르다. 그러나 연해주 지역의 경우, 동풍을 타고 미세먼지가 유입되는 일은 한반도와 달리 덜 받는 것으로 보인다.
#
# 미세먼지 구성 성분
# 미세먼지의 구성 성분은 질산염과 황산염 등이 58.3%, 탄소류와 검댕 16.8%, 광물 6.3%, 기타 18.6%로 이루어져있다.
#
# 질병
# 노인사망률 증가
# 2009년 국립환경과학원과 인하대 연구팀의 미세먼지와 사망률 연구 결과, 서울에서 미세먼지(PM10) 농도가 ㎥당 10㎍(100만분의 1g) 증가할 때마다 65살 이상 노인 등 대기오염에 민감한 집단의 사망률은 0.4%씩 증가하는 것으로 파악했다. 초미세먼지(PM2.5)의 영향은 더 커서 10㎍/㎥ 증가할 때마다 민감집단의 사망률은 1.1% 늘어나는 것으로 추정했다.
#
# 임산부와 태아
# 이화여대 의대 하은희 교수팀의 연구 결과 미세먼지 농도가 10㎍/㎥ 올라가면 저체중아 출산 위험이 5.2%에서 7.4%까지 높아지고, 임신 4~9개월 사이의 사산 위험도 8.0~13.8%까지 올라가는 것으로 조사됐다.2009년 양산부산대병원 산업의학 전문의, 대기과학 및 지리정보시스템 전문가들이 공동으로 연구를 진행한 결과, 미세먼지(PM10, 직경이 10μm 이하의 먼지) 농도가 저체중아 출산 및 사산, 기형아 발생과 밀접한 관계가 있는 것으로 조사됐다.국경없는의사회(MSF)의 1998년 조사 결과 투르크메니스탄의 아랄해 인접지역은 먼지 퇴적률이 아주 높았으며 살충제의 오염도 심한 것으로 나왔다. 2000~2001년 카라칼파크 지역의 먼지와 호흡기 질환의 상관관계 조사에서는 건강에 위협적인 미세먼지가 전체 먼지 가운데 14~53%에 이르는 것으로 나타났으며, 이 지역 어린이들의 폐활량 등 폐기능이 유럽 어린이에 비해 현저히 낮은 것으로 나타났다.미국의 한 대학병원이 아동 천7백 명을 조사한 연구를 보면, 미세먼지 농도가 짙은 지역에서 태어난 아이들은 그렇지 않은 지역에서 태어난 아이들보다 폐활량이 정상의 80%에 못 미치는 '폐 기능장애'를 겪을 가능성이 커지는 것으로 조사됐다. 이런 사실 때문에 전문가들은 미세먼지를 '조용한 살인자'라고 부른다.
#
# 천식
# 사람의 폐포까지 깊숙하게 침투해 기관지와 폐에 쌓인 미세먼지는 각종 호흡기 질환의 직접 원인이 되며 몸의 면역 기능을 떨어뜨린다. 천식과 호흡곤란을 일으키며 장거리 이동으로 비 또는 눈속의 중금속 농도를 증가시키기도 한다. 또한 대기 중에 부유하면서 빛을 흡수, 산란시키기 때문에 시야를 악화시키기도 하고, 식물의 잎 표면에 쌓여 광합성 동화작용, 호흡작용과 증산작용 등을 저해하여 식물 성장에도 나쁜 영향을 미친다. 또한 여성의 사망원인중 88%가 조리 과정에서 발생한 미세먼지에 의한 사망이라고 한다.
# 한국환경정책평가연구원 조승헌 박사팀의 연구결과에 따르면, 미세먼지를 10∼30% 감축하면 수도권의 관련 질환 사망자 수가 해마다 40∼120명 줄어들고 심장 및 호흡기 질환 건수는 연간 2800∼8300건 줄일 수 있는 것으로 전망했다. 또 심장 및 호흡기계통 질환과 관련된 의료비용 등을 토대로 미세먼지 감축으로 인한 이익을 계산한 결과 연간 80억∼1200억원에 이르는 것으로 풀이했다.
#
# 두통
# 무연탄을 태울 때 나오는 신경계 독성물질인 납이나 비소, 아연 등 유해 중금속 농도가 높은 미세먼지를 마시면 멀쩡하던 사람도 기침하게 되고 목이 아프고, 피부 트러블을 일으키기도 한다. 머리가 굉장히 아프거나 어지러움, 호흡곤란 등이 생긴다.
# 대부분의 미세먼지가 치명적이지만 그중에서도 황산이온이나 질산이온 등은 황사 속 먼지와 흡착되면서 산화물로 변해 호흡과 함께 폐로 들어가게 된다. 이 물질이 폐로 들어가면 염증을 일으키는데, 기관지염이나 천식, 만성폐쇄성폐질환(COPD)이 대표적이다. 이런 물질들은 백혈구를 자극해 혈관벽에도 염증을 일으킬 수 있다. 이렇게 되면 전형적인 혈관질환인 동맥경화, 뇌경색, 심근경색 등을 유발할 수 있다.
#
# 아토피
# 모공보다 더 작은 초미세먼지는 모공으로 침투해 아토피 등 피부염의 원인이 되기 때문에 여드름이 있거나 아토피가 있는 사람들 역시 황사가 온다는 예보에는 야외활동을 자제하는 것이 좋다.
#
# 인슐린 저항성
# 대기오염 미세먼지의 주성분인 노년여성의 인슐린 저항성을 높인다는 연구 결과가 나왔다. 인슐린 저항성(IR)은 혈당을 낮추는 인슐린의 기 혈당을 효과적으로 사용하지 못해 대사증후군은 물론 심장병·당뇨병 등까지 초래할 수 있다.
#
# 예방과 대책
# 사전에 미세먼지 농도를 확인한 후, 농도에 따라 활동범위를 정한다.
# 어린이, 노인, 폐질환 및 심장질환자 등 민감군은 실외 활동을 제한하고 그렇지 않은 사람들은 장시간 또는 무리한 실외 활동을 줄인다.
# 미세먼지로부터 보호할 수 있는 가장 간단하고 보편적인 방법은 미세먼지 차단 마스크를 착용하는 것이다. 미세먼지 차단 성능이 있는 마스크는 제품 포장에 '의약외품'이라는 문자와 KF80, KF94, KF99 등이 표시되어 있다. KF80, KF94, KF99는 입자차단 성능을 나타내는데 KF80은 평균 0.6μm 크기의 미세입자를 80퍼센트 이상 걸러낼 수 있으며, KF94, KF99는 0.4μm 크기의 미세입자를 94퍼센트, 99퍼센트 이상 각각 걸러낼 수 있다.
# 전 지구적인 문제이므로 각 나라의 수장들이 모여 정책을 마련할 필요가 있다.
#
# 같이 보기
# 먼지
# 대기질 지수
# 석유코크(페트코크, en:Petroleum coke, petcoke)
# 마스크 - 착용 필요한 도구.
#
# 각주 및 참고 문헌
# 본 문서에는 서울특별시에서 지식공유 프로젝트를 통해 퍼블릭 도메인으로 공개한 저작물을 기초로 작성된 내용이 포함되어 있습니다.
#
# 외부 링크
#  위키미디어 공용에 미세먼지 관련 미디어 분류가 있습니다.
# 에어 코리아 - 대한민국 실시간 대기오염도

# %%
wiki2 = wikipediaapi.Wikipedia(language='ko', extract_format=wikipediaapi.ExtractFormat.WIKI) 
p_wiki2 = wiki2.page("스모그") 
print(p_wiki2.text)
# Out:
# 스모그(영어: smog)는 대기 오염의 하나이다. 스모크(smoke)와 포그(fog)가 결합된 말로 원래는 연기와 안개가 섞인 것을 가리키는 말이었지만, 현대에 와서 대기 오염 물질로 하늘이 뿌옇게 보이는 현상을 부르는 말로 쓰이게 되었다. 자동차 배기 가스나 화력 발전소·공장 등에서 나오는 대기 오염 물질 때문에 생긴다. 대도시에서 많이 생기지만, 바람에 실려가 다른 곳에 피해를 주기도 한다.
#
# 형태
# 스모그는 바람이 약하거나 기온역전과 같은 기상 상태에서 발생하기 쉽다. 기온역전의 기상 조건에서는 스모그가 높이 올라가 흩어지는 것을 막으며, 도시 근처의 산맥도 스모그를 잡아두는 데 한몫을 한다. 스모그로 인한 피해를 살펴보면, 1948년 미국 펜실베이니아주의 도노라에서 발생한 광화학스모그로, 20여 명이 사망하고 6,000명 가량이 병에 걸렸다. 1952년에는 영국의 런던에서 발생한 스모그 집중현상으로는 5일 동안 약 4,000명이 사망했다. 스모그는 식물도 죽이며, 건축자재의 부식도 빨리 진행시킨다.  서울의 스모그는 주로 미세먼지의 오염이 심하고, 대기중 습도가 높으며, 바람이 없는 날에 발생한다. 스모그가 발생하면 하늘이 뿌옇고 볼 수 있는 거리가 짧아져, 대기오염이 심하다고 느끼게 된다. 겨울과 봄에는 난방이나 산업 연료의 연소 중에 나오는 황산화물과 먼지 때문에 스모그가 발생하고 여름에는 자동차에서 나오는 질소산화물과 탄화수소의 광화학반응으로 스모그가 발생한다. 스모그의 주요 원인인 미세먼지에는 연료가 연소하는 과정에서 발생하는 성분과 자동차에서 발생하는 성분이 함께 들어 있다.
# 런던형 스모그 (황화 스모그): 화석연료를 태워서 생긴 이산화황, 일산화탄소 때문에 생긴다.
# LA형 스모그 (광화학 스모그): 자동차 배기 가스에 들어 있는 질소 산화물로 인해 생긴다.
# 화산 스모그: 자연적으로 생기는 스모그로, 화산 폭발로 분출된 이산화황 때문에 생긴다.
# 혼합형 스모그 (서울 스모그): 런던형 스모그와 LA형 스모그가 같이 일어나는 현상이다.
#
# 정의
# 영어의 ‘smoke’(연기)와 ‘fog’(안개)의 합성어이다.
# 이 용어는 1905년 H. A. 데 보외가 영국 도시들의 대기 상태를 지칭하는 말로 처음 사용했다. 1911년 매연감소를 위한 전국연맹의 맨체스터 회의에서 데 보외가 1909년 가을 글래스고와 에든버러에서 '매연-안개'로 인해 1,000명 이상의 사상자가 생겼던 사건을 보고하면서 보편화되었다.
#
# 원인물질과 배출원
# 아황산가스 : 공장, 빌딩 등의 연소시설이나 산업체 및 가정 등의 난방시설이 주요 배출원이나, 최근에는 연료 개선 정책에 의해 배출량이 상당히 감소하였다.질소산화물 : 질소산화물은 연료의 연소시 고온에 의하여 공기중의 질소와 산소가 반응하여 생성되는 것으로서, 주요 배출원은 자동차, 기차, 비행기, 선박과같은 이동 배출원과 산업장, 빌딩 및 가정용 보일러와 같은 고정 배출원이라고 알려져 있다.VOCS(휘발성유기화합물) : 석유의 불완전 연소와 정발에 의해서 배출되므로 자동차, 페인트 용매, 인쇄 시설 등이 주요 배출원이며, 그 밖에 주유소, 정유시설, 저유소, 세탁소,아스팔트 등과 같이 배출원이 다양하다. 유럽과 미국의 교외지역 에서는 산림에서 배출되는 자연배출 VOC도 오존 생성의 주요 원인물질로서 기여하고 있는 것으로 보고됨.미세먼지 : 시정이 나빠지는 것은 에어로솔이 빛을 산란시키거나 흡수하여 소멸시키기 때문에 입자의 주요 성분은 황산염, 질산염, 원소탄소, 유기탄소들이다. PM-10도 시정과 상관관계는 있으나 시정에 직접적으로 중요한 것은 PM-2.5이다. TSP는 미세입자 비율이 높지 않은 한 그 자체만으로는 시정과 관계가 없다.안개 : 기온의 급강하로 아침에 주로 생기는 안개의 현상이 시계를 방해하는 물질중의 하나이다. 서울의 경우 과거보다 더 많은 양의 안개현상이 나타날 뿐 아니라 기온이 올라가도 예년같이 잘 소멸되지 않는 이유중의 하나로 안개를 끼게 만드는 미세입자들의 존재가 기여하는 것으로 추정된다.탄화수소 : 불완전연소와 증발에 의해서 배출되므로 자동차가 주요한 배출원이며 정유시설, 저유소 및 정유소의 연료탱크에서 증발되는 연료, 체인트 용매, 세탁소에서 사용하는 용매등도 탄화수소의 주요한 배출원이다.
#
# 종류
# 스모그는 크게 LA형 스모그와 런던형 스모그로 나뉜다. 원래 스모그가 석탄이 연소한 데에서 나온 여러 가지 결과물이 안개와 섞여서 회색 안개가 되는 식으로 발생한 것과 달리, 광화학스모그는 자동차 배기가스 같이 석유 연료가 연소된 후, 이후 빛을 받아서 화학반응을 일으키는 과정을 통해 생물에 유해한 화합물이 만들어져서 옅은 황갈색 안개가 된다. 이러한 광화학스모그는 미국 로스엔젤레스에서 처음 발생이 확인되었기 때문에, 과거 스모그를 '런던형 스모그'라고 부르고 광화학스모그를 '로스앤젤레스형 스모그'라고 부르기도 한다.
#
# LA형 스모그(광화학 스모그)
# 로스앤젤레스형 스모그는 주로 자동차의 배기가스 속에 함유된 올레핀계 탄화수소와 질소산화물의 혼합물에 태양광선이 작용해서 생기는 광화학반응에 의한 것이며, 광화학스모그라고도 한다.
#
# 런던형 스모그(황화 스모그)
# 주로 공장 및 빌딩의 연소시설이나 일반 가정난방시설 등에서 배출되는 아황산가스, 매연과 같이 직접 굴뚝에서 나오는 오염물질에 의하여 발생하는 스모그이다. 겨울철 밤과 새벽에 심하다.
#
# 피해상황
# 배출된 연기와 짙은 안개가 합쳐져 스모그를 형성하였고, 특히 연기 속에 있던 아황산가스는 황산안개로 변하였다. 그리고 이것은 런던 시민의 호흡기에 치명적인 영향을 주게 되었다.  이러한 현상은 12월 10일까지 1주일간 지속되었으며, 런던 시민은 호흡장애와 질식 등으로 사건 발생후 첫 3주 동안에 4천여명이 사망하였다. 그 후, 만성 폐질환으로 8천명이 추가로 사망하여 총 1만 2천여명이 1주일 동안의  심한 대기오염 현상으로 인하여 생명을 잃었다.
# 이 사건이 일어난 1주일 동안 시민들은 런던을 떠나 다른 곳으로 피신하는 것 외에는 아무런 대책을 세울 수 없었으며, 기상변화에 의해 대기가 회복되기를 기다리는 것 이외에는 달리 방책이 없었다. 역사상 영국 런던은 안개와 석탄으로 인한 대기오염 피해 사례가 처음으로 보고된 곳이다.
# 1991년 12월 10일의 구로동 전철불통(30분간)은 철도청구로기지변전소의 정전사고 원인이 차량배기가스로 인한 아연도강선 부식으로 밝혀짐.
# 서울 스모그 우려 - 광화학스모그(햇빛의 자외선 + 차량오염물질) = 맑은 날에도 안개낀 것 같은 상태, 시정장애 연 60일 발생.
# 인천, 대기에서 발암물질인 휘발성 유기화합물(voc)이 미국 기준치의 최고 6배 이상검출.
#
# 대책
# 정유과정에서 황을 제거하여 저유황 경유나 중유를 만들어 사용하면 이산화황의 배출량이 감소한다.
# 발전소나 공장에 이산화황 제거장치(탈황장치)를 설치한다.
# 자동차에 촉매변환장치를 부착하여 배기가스 속의 질소 산화물을 이산화탄소와 질소로 분해시킨다.
# 코트렐 집진기를 설치하여 분진의 배출량을 감소시킨다.
#
# 결과
# 1990년대 초부터 적극적인 환경정책이 추진됨. 첫 5년동안 47억 달러를 투자, 저공해 연료교체, 배출규제 강화, 공해 산업이전, 나대지 식생복원, 차없는 날 제정 등 112개 프로젝트를 시행. 그결과 일산화탄소, 황산화물, 오존이 삼분의 일 수준으로 질소산화물과 미세먼지가 이분의 일 수준으로 감소.
#
# 같이 보기
# 오존층
# 산성비
# 황사
#
# 각주
# 출처 및 외부 링크
# 조윤승(1991), 스모그와 건강피해 - 런던스모그참사의 재조명, 대한환경위생공학회지, pp.109~120
# 서인호(2000), 고교생이 알아야 할 화학 스페셜, 신원문화사
# 중국의 스모그 피해: https://web.archive.org/web/20090726015245/http://www.kfem.or.kr/kbbs/bbs/board.php?bo_table=envnews
# 베이징 스모그 잡기: http://coolmoney.mt.co.kr/view/coolview.php?no=2008042513144463756
# 네이버 국어사전 - 스모그
# 네이버(두산) 백과사전 - 스모그
# 네이버(두산) 백과사전 - 탈황
# 네이버(두산) 백과사전 - 전기집진기

# %%
from konlpy.tag import Twitter
from collections import Counter
nlpy1 = Twitter()
nouns1 = nlpy1.nouns(p_wiki1.text)
print(nouns1)
# Out:
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ['미세먼지', '영어', '분진', '은', '눈', '보이지', '정도', '입자', '먼지', '아황산가스', '질소', '산화물', '납', '오존', '일산', '탄소', '등', '포함', '대기오염', '물질', '자동차', '공장', '조리', '과정', '등', '발생', '대기', '중', '장기간', '입경', '입자', '지름', '이하', '먼지', '입자', '이하', '경우', '초미세먼지', '미세먼지', '학술', '에어로졸', '미세먼지', '부유', '분진', '입자', '물질', '등', '불리', '명칭', '약간', '다른', '의미', '가지', '입자', '물질', '지름', '나노미터', '정도', '이보', '지름', '중력', '대기', '체류', '시간', '아주', '개요', '인체', '영향', '물질', '미국', '펜실베이니아주', '도', '명', '사망', '대기오염', '사고', '약', '명의', '사망자', '발생', '런던', '스모그', '미세먼지', '인체', '영향', '대표', '사례', '그', '이후', '미세먼지', '인체', '영향', '대한', '역학', '조사', '실시', '이하', '미세먼지', '입자', '취약', '집단', '질병', '발생', '률', '사망률', '등', '인체', '영향', '가능성', '것', '이후', '각', '국', '대기오염', '대책', '마련', '미세먼지', '인체', '환경', '영향', '위해', '대기오염', '기준', '마련', '미세먼지', '입자', '크기',
�소', '류', '검댕', '광물', '기타', '로', '질병', '노인', '사망률', '증가', '국립', '환경과학', '인하대', '팀', '미세먼지', '사망률', '연구', '결과', '서울', '미세먼지', '농도', '당', '증가', '때', '살', '이상', '노인', '등', '대기오염', '집단', '사망률', '증가', '것', '파악', '초미세먼지', '의', '영향', '더', '커서', '증가', '때', '민감', '집단', '사망률', '것', '추정', '임산부', '태아', '이화여대', '의대', '하은', '교수', '팀', '연구', '결과', '미세먼지', '농도', '저체중', '출산', '위험', '임신', '개월', '사이', '사산', '위험', '것', '조사', '양산', '부산', '병원', '산업의학', '전문의', '대기과학', '및', '지리', '정보', '시스템', '전문가', '공동', '연구', '진행', '결과', '미세먼지', '직경', '이하', '먼지', '농도', '저체중', '출산', '및', '사산', '기형', '발생', '관계', '것', '조사', '국경없는의사회', '의', '조사', '결과', '투르크메니스탄', '아랄해', '인접', '지역', '먼지', '퇴적', '률', '아주', '살충제', '오염', '것', '카라칼', '파크', '지역', '먼지', '호흡기', '질환', '상관관계', '조사', '건강', '위협', '미세먼지', '전체', '먼지', '가운데', '것', '이', '지역', '어린이', '폐활량', '등', '폐기', '능이', '유럽', '어린이', '현저', '것', '미국', '대학병원', '아동', '천', '백', '명', '조사', '연구', '미세먼지', '농도', '지역', '아이', '지역', '아이', '폐활량', '정상', '못', '폐', '기능', '장애', '를', '가능성', '것', '조사', '사실',  ...

# %%
count = Counter(nouns1)
tag_count = []
tags = []
for n, c in count.most_common():
    dics = {'tag': n, 'count': c}
    if len(dics['tag']) >= 2 and len(tags) <= 49:
        tag_count.append(dics)
        tags.append(dics['tag'])
for tag in tag_count:
    print(" {:<14}".format(tag['tag']), end='\t')
    print("{}".format(tag['count']))
# Out:
#  미세먼지          	42
#  입자            	25
#  먼지            	21
#  발생            	17
#  지역            	16
#  영향            	12
#  평균            	12
#  물질            	10
#  크기            	9
#  원인            	9
#  경우            	8
#  인체            	8
#  질환            	8
#  결과            	8
#  농도            	8
#  대기오염          	7
#  이하            	7
#  조사            	7
#  기준            	7
#  지름            	5
#  부유            	5
#  사망률           	5
#  미만            	5
#  때문            	5
#  가장            	5
#  호흡기           	5
#  증가            	5
#  연구            	5
#  대기            	4
#  초미세먼지         	4
#  환경            	4
#  범위            	4
#  이상            	4
#  침투            	4
#  기도            	4
#  중국            	4
#  사람            	4
#  호흡            	4
#  활동            	4
#  인슐린           	4
#  분진            	3
#  정도            	3
#  미국            	3
#  집단            	3
#  마련            	3
#  폐포            	3
#  기능            	3
#  설정            	3
#  건강            	3
#  미세            	3

# %%
nlpy2 = Twitter()
nouns2 = nlpy2.nouns(p_wiki2.text)
print(nouns2)
# Out:
# ['스모그', '영어', '대기', '오염', '하나', '스모크', '포그', '결합', '말로', '원래', '연기', '안개', '것', '현대', '대기', '오염', '물질', '하늘', '현상', '말로', '자동차', '배기', '가스나', '화', '발전소', '공장', '등', '대기', '오염', '물질', '때문', '대도시', '생기', '바람', '다른', '곳', '피해', '주기도', '형태', '스모그', '바람', '기온역전', '기상', '상태', '발생', '기온역
그', '석탄', '연소', '데', '여러', '가지', '결과물', '안개', '회색', '안개', '식', '발생', '것', '달리', '광화학', '스모그', '자동차', '배기가스', '석유', '연료', '연소', '후', '이후', '빛', '화학반응', '과정', '통해', '생물', '화합물', '황', '갈색', '안개', '광화학', '스모그', '미국', '로스엔젤레스', '처음', '발생', '확인', '때문', '과거', '스모그', '런던', '스모그', '광화학', '스모그', '로스앤젤레스', '스모그', '기도', '형', '스모그', '광화학', '스모그', '로스앤젤레스', '스모그', '주로', '자동차', '배기가스', '속', '함유', '올레', '탄화수소', '질소', '산화물', '혼합물', '태양', '광선', '작용', '광화학', '반응', '것', '광화학', '스모그', '고도', '런던', '스모그', '황화', '스모그', '주로', '공장', '및', '빌딩', '시설', '일반', '가정', '난방', '시설', '등', '배출', '아황산가스', '매연', '직접', '굴뚝', '오염', '물질', '발생', '스모그', '겨울철', '밤', '새벽', '피해', '상황', '배출', '연기', '안개', '스모그', '형성', '연기', '속', '아황산가스', '황산', '안개', '것', '런던', '시민', '호흡기', '치명', '영향', '현상', '일간', '지속', '런던', '시민', '호흡', '장애', '질식', '등', '사건', '발생', '후', '첫', '주', '동안', '사망', '그', '후', '만성', '폐', '질환', '추가', '사망', '총', '주일', '동안', '대기오염', '현상', '생명', '이', '사건', '주일', '동안', '시민', '런던', '다른', '곳', '피신', '것', '외', '대책', '수', '기상', '변화', '대기', '회복', '것', '이외', '달리', '방책', '역사상', '영국', '런던', '안개', '석탄', '대기오염', '피해', '사례', '처음', '보고', '곳', '일찍이', '산업혁명', '이전', '에드워드', '세계', '최초', '대기오염', '방지', '위', '석탄', '용량', '칙령', '발표', '바', '칙령', '발표', '위반', '대해', '사형', '처', '내용', '기록', '그', '후', '산업혁명', '시대', '대기오염', '더욱', '환경', '재난', '고후', '조치', '등', '피해', '런던', '동일', '지역', '원인', '환경', '재난', '가장', '곳', '기록', '그', '중', '앞서', '기술', '재난', '피해', '가장', '계기', '영국', '비버', '위원회', '설립', '대기오염', '실태', '대책', '조사', '연구', '시작', '이', '위원회', '제출', '보고서', ' ...

# %%
count = Counter(nouns2)
tag_count = []
tags = []
for n, c in count.most_common():
    dics = {'tag': n, 'count': c}
    if len(dics['tag']) >= 2 and len(tags) <= 49:
        tag_count.append(dics)
        tags.append(dics['tag'])
for tag in tag_count:
    print(" {:<14}".format(tag['tag']), end='\t')
    print("{}".format(tag['count']))
# Out:
#  스모그           	53
#  배출            	17
#  발생            	15
#  안개            	14
#  런던            	14
#  광화학           	12
#  자동차           	10
#  피해            	10
#  물질            	9
#  대기오염          	9
#  질소            	9
#  현상            	8
#  연료            	8
#  대기            	7
#  때문            	7
#  산화물           	7
#  주요            	7
#  사건            	7
#  시설            	7
#  오염            	6
#  사망            	6
#  동안            	6
#  주로            	6
#  연소            	6
#  원인            	6
#  질환            	6
#  미국            	5
#  탄화수소          	5
#  감소            	5
#  보고            	5
#  시정            	5
#  배기가스          	5
#  연기            	4
#  공장            	4
#  영국            	4
#  서울            	4
#  미세먼지          	4
#  난방            	4
#  반응            	4
#  이산화황          	4
#  가정            	4
#  정유            	4
#  오존            	4
#  석탄            	4
#  시민            	4
#  호흡기           	4
#  호흡            	4
#  환경            	4
#  네이버           	4
#  말로            	3

# %%
G=nx.DiGraph()
G1=nx.DiGraph()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
import string
# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='NanumGothic') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
text1=[]
text1=p_wiki1.text.split(".")

# %%
text2=[]
text2=p_wiki2.text.split(".")

# %%
i=0
for each_line in text1:
#for i in range (len(nouns1)):
    if each_line.find(nouns1[i])>0:
        nlpy3 = Twitter()
        nouns3 = nlpy3.nouns(each_line)
        print(nouns3)
# Out:
# ['초미세먼지', '미세먼지']
# ['미세먼지', '부유', '분진', '입자', '물질', '등', '불리', '명칭', '약간', '다른', '의미', '가지']
# ['미국', '펜실베이니아주', '도', '명', '사망', '대기오염', '사고', '약', '명의', '사망자', '발생', '런던', '스모그', '미세먼지', '인체', '영향', '대표', '사례']
# ['그', '이후', '미세먼지', '인체', '영향', '대한', '역학', '조사', '실시', '이하', '미세먼지', '입자', '취약', '집단', '질병', '발생', '률', '사망률', '등', '인체', '영향', '가능성', '것']
# ['이후', '각', '국', '대기오염', '대책', '마련', '미세먼지', '인체', '환경', '영향', '위해', '대기오염', '기준', '마련']
# ['미세먼지', '입자', '크기', '이하', '먼지', '입자', '크기', '매우', '미세먼지', '구분']
# ['미세먼지', '지름', '미세먼지', '지름']
# ['미세먼지']
# ['것', '초미세먼지']
# ['발생', '원인', '미세먼지', '배출', '원인', '인위', '발생', '자연', '발생', '구분']
# ['인위', '발생', '원인', '중국', '발', '미세먼지', '공장', '매연', '쓰레기', '소각', '항만', '지역', '가정', '생선', '그', '외', '것', '구울', '때', '등']
# ['발생', '국가', '중국', '한국', '중국', '경우', '세계', '화석', '연료', '가장', '소비', '나라', '손', '베이징시', '톈진시', '칭다오시', '등', '동부', '지역', '고비', '사막', '인접', '곳도', '역시', '미세먼지', '범', '등', '아시아', '최대', '미세먼지', '발생', '원인', '공국', '손']
# ['다만', '미세먼지', '주로', '건기', '겨울', '가장', '발생', '한반도', '북한', '전', '지역', '대한민국', '새만금', '이북', '지역', '중', '간지', '영향', '강원도', '영동', '지방', '경상북도', '북부', '동해안', '울릉도', '독도', '제외', '중부', '전', '지역', '남부', '일부', '지역', '발생']
# ['일본', '경우', '미세먼지', '규슈', '이키', '섬', '쓰시마섬', '등지', '간', '적', '발생', '경우', '것']
# ['우리나라', '중국', '미세먼지', '피해', '러시아', '러시아', '체적', '미세먼지', '발생량', '지역', '편차']
# ['연해주', '지역', '경우', '동풍', '타고', '미세먼지', '유입', '일', '한반도', '달리', '덜', '것']
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ['미세먼지', '구성', '성분', '미세먼지', '구성', '성분', '질산염', '황산염', '등']
# ['질병', '노인', '사망률', '증가', '국립', '환경과학', '인하대', '팀', '미세먼지', '사망률', '연구', '결과', '서울', '미세먼지', '농도', '당', '증가', '때', '살', '이상', '노인', '등', '대기오염', '집단', '사망률']
# ['초미세먼지']
# ['임산부', '태아', '이화여대', '의대', '하은', '교수', '팀', '연구', '결과', '미세먼지', '농도', '저체중', '출산', '위험']
# ['양산', '부산', '병원', '산업의학', '전문의', '대기과학', '및', '지리', '정보', '시스템', '전문가', '공동', '연구', '진행', '결과', '미세먼지', '직경', '이하', '먼지', '농도', '저체중', '출산', '및', '사산', '기형', '발생', '관계', '것', '조사']
# ['카라칼', '파크', '지역', '먼지', '호흡기', '질환', '상관관계', '조사', '건강', '위협', '미세먼지', '전체', '먼지', '가운데', '것', '이', '지역', '어린이', '폐활량', '등', '폐기', '능이', '유럽', '어린이', '현저', '것']
# ['미국', '대학병원', '아동', '천', '백', '명', '조사', '연구', '미세먼지', '농도', '지역', '아이', '지역', '아이', '폐활량', '정상', '못', '폐', '기능', '장애', '를', '가능성', '것', '조사']
# ['사실', '때문', '전문가', '미세먼지', '살인자']
# ['천식', '사람', '폐포', '침투', '기관지', '폐', '미세먼지', '각종', '호흡기', '질환', '직접', '원인', '몸', '면역', '기능']
# ['또한', '여성', '사망원인', '조리', '과정', '발생', '미세먼지', '사망']
# ['한국', '환경', '정책', '평가', '연구원', '승헌', '박사', '팀', '결과', '미세먼지', '감축', '수도권', '관련', '질환', '사망자', '수가', '명', '심장', '및', '호흡기', '질환', '건수', '연간', '건', '수', '것', '전망']
# ['또', '심장', '및', '호흡기', '계통', '질환', '관련', '의료', '비용', '등', '토대', '미세먼지', '감축', '이익', '계산', '결과', '연간', '것', '풀이']
# ['두통', '무연탄', '때', '신경계', '독성', '물질', '납', '비소', '아연', '등', '유해', '중금속', '농도', '미세먼지', '사람', '기침', '목', '피부', '트러블', '기도']
# ['대부분', '미세먼지', '치명', '중', '황산', '이온', '질산', '이온', '등', '황사', '속', '먼지', '흡착', '산화물', '호흡', '폐']
# ['아토피', '모공', '더', '초미세먼지', '모공', '침투', '아토피', '등', '피부염', '원인', '때문', '여드름', '아토피', '사람', '역시', '황사', '예보', '야외', '활동', '자제', '것']
# ['인슐린', '저항', '대기오염', '미세먼지', '주성분', '노년', '여성', '인슐린', '저항', '연구', '결과']
# ['예방', '대책', '사전', '미세먼지', '농도', '확인', '후', '농도', '활동', '범위', '정']
# ['미세먼지', '로부터', '보호', '수', '가장', '보편', '방법', '미세먼지', '차단', '마스크', '착용', '것']
# ['미세먼지', '차단', '성능', '마스크', '제품', '포장', '의약외품', '문자', '등', '표시']
# ['외부', '링크', '위키미디어', '공용', '미세먼지', '관련', '미디어', '분류']

# %%
i=0
for each_line in text2:
#for i in range (len(nouns1)):
    if each_line.find(nouns2[i])>0:
        nlpy4 = Twitter()
        nouns4 = nlpy4.nouns(each_line)
        print(nouns4)
# Out:
# ['형태', '스모그', '바람', '기온역전', '기상', '상태', '발생']
# ['기온역전', '기상', '조건', '스모그', '높이', '것', '도시', '근처', '산맥', '스모그', '데', '한몫']
# ['스모그', '피해', '미국', '펜실베이니아주', '도', '발생', '광화학', '스모그', '여', '명', '사망', '명', '가량', '병']
# ['영국', '런던', '발생', '스모그', '집중', '현상', '동안', '약', '명', '사망']
# ['스모그', '식물', '죽', '건축', '재의', '부식', '진행']
# ['서울', '스모그', '주로', '미세먼지', '오염', '대기', '습도', '바람', '날', '발생']
# ['스모그', '발생', '하늘', '볼', '수', '거리', '대기오염']
# ['겨울', '봄', '난방', '산업', '연료', '연소', '중', '황산', '화물', '먼지', '때문', '스모그', '발생', '여름', '자동차', '질소', '산화물', '탄화수소', '광화학', '반응', '스모그', '발생']
# ['스모그', '주요', '원인', '미세먼지', '연료', '연소', '과정', '발생', '성분', '자동차', '발생', '성분']
# ['런던', '스모그', '황화', '스모그', '화석연료', '이산화황', '일산화탄소', '때문']
# ['형', '스모그', '광화학', '스모그', '자동차', '배기', '가스', '질소', '산화물']
# ['화산', '스모그', '자연', '스모그', '화산', '폭발', '분출', '이산화황', '때문']
# ['혼합형', '스모그', '서울', '스모그', '런던', '스모그', '형', '스모그', '현상']
# ['종류', '스모그', '크게', '형', '스모그', '런던', '스모그']
# ['원래', '스모그', '석탄', '연소', '데', '여러', '가지', '결과물', '안개', '회색', '안개', '식', '발생', '것', '달리', '광화학', '스모그', '자동차', '배기가스', '석유', '연료', '연소', '후', '이후', '빛', '화학반응', '과정', '통해', '생물', '화합물', '황', '갈색', '안개']
# ['광화학', '스모그', '미국', '로스엔젤레스', '처음', '발생', '확인', '때문', '과거', '스모그', '런던', '스모그', '광화학', '스모그', '로스앤젤레스', '스모그', '기도']
# ['형', '스모그', '광화학', '스모그', '로스앤젤레스', '스모그', '주로', '자동차', '배기가스', '속', '함유', '올레', '탄화수소', '질소', '산화물', '혼합물', '태양', '광선', '작용', '광화학', '반응', '것', '광화학', '스모그', '고도']
# ['런던', '스모그', '황화', '스모그', '주로', '공장', '및', '빌딩', '시설', '일반', '가정', '난방', '시설', '등', '배출', '아황산가스', '매연', '직접', '굴뚝', '오염', '물질', '발생', '스모그']
# ['피해', '상황', '배출', '연기', '안개', '스모그', '형성', '연기', '속', '아황산가스', '황산', '안개']
# ['광화학', '스모그', '경우', '인체', '영향', '주로', '눈']
# ['벤젠', '톨루엔', '등', '햇빛', '등', '반응', '광화학', '스모그', '장기간', '인체', '노', '출시', '백혈병', '암', '등', '유발', '수']
# ['런던', '스모그', '사건', '사건', '발생', '후', '첫', '주', '동안', '호흡', '장애', '질식', '등', '여명', '시민', '사망', '그', '후', '만성', '폐', '질환', '명', '추가', '사망', '총', '명', '동안', '대기오염', '현상', '생명']
# ['멕시코', '시티', '스모그', '도시', '차량', '배기가스', '매연', '분진', '오존', '불량', '지수', '생활환경', '위험', '지표', '배', '초과']
# ['서울', '스모그', '우려', '광화학', '스모그', '햇빛', '자외선', '차량', '오염', '물질', '맑은', '날', '안개', '것', '상태', '시정', '장애', '연', '발생']
# ['보기', '오존층', '산성비', '황사', '각주', '출처', '및', '외부', '링크', '조윤승', '스모그', '건강', '피해', '런던', '스모그', '참사', '재', '조명', '환경', '위생', '학회']
# ['인호', '고교생', '화학', '스페셜', '화사', '중국', '스모그', '피해']
# ['베이징', '스모그', '잡기']
# ['네이버', '국어사전', '스모그', '네이버', '두산', '백과사전', '스모그', '네이버', '두산', '백과사전', '탈황', '네이버', '두산', '백과사전', '전기']

# %%
i=0
for each_line in text1:
#for i in range (len(nouns1)):
    if each_line.find(nouns1[i])>0:
        nlpy3 = Twitter()
        nouns3 = nlpy3.nouns(each_line)
        G.add_nodes_from(nouns3)
        for j in range (len(nouns3)):
            for l in range (len(nouns3)):
                if nouns3[j]!=nouns3[i]:
                    print(nouns3[j],nouns3[i])
                    G.add_edges_from([(nouns3[j],nouns3[i])])
                    G.add_edges_from([(nouns3[i],nouns3[j])])
                    break
# Out:
# 미세먼지 초미세먼지
# 부유 미세먼지
# 분진 미세먼지
# 입자 미세먼지
# 물질 미세먼지
# 등 미세먼지
# 불리 미세먼지
# 명칭 미세먼지
# 약간 미세먼지
# 다른 미세먼지
# 의미 미세먼지
# 가지 미세먼지
# 펜실베이니아주 미국
# 도 미국
# 명 미국
# 사망 미국
# 대기오염 미국
# 사고 미국
# 약 미국
# 명의 미국
# 사망자 미국
# 발생 미국
# 런던 미국
# 스모그 미국
# 미세먼지 미국
# 인체 미국
# 영향 미국
# 대표 미국
# 사례 미국
# 이후 그
# 미세먼지 그
# 인체 그
# 영향 그
# 대한 그
# 역학 그
# 조사 그
# 실시 그
# 이하 그
# 미세먼지 그
# 입자 그
# 취약 그
# 집단 그
# 질병 그
# 발생 그
# 률 그
# 사망률 그
# 등 그
# 인체 그
# 영향 그
# 가능성 그
# 것 그
# 각 이후
# 국 이후
# 대기오염 이후
# 대책 이후
# 마련 이후
# 미세먼지 이후
# 인체 이후
# 환경 이후
# 영향 이후
# 위해 이후
# 대기오염 이후
# 기준 이후
# 마련 이후
# 입자 미세먼지
# 크기 미세먼지
# 이하 미세먼지
# 먼지 미세먼지
# 입자 미세먼지
# 크기 미세먼지
# 매우 미세먼지
# 구분 미세먼지
# 지름 미세먼지
# 지름 미세먼지
# 초미세먼지 것
# 원인 발생
# 미세먼지 발생
# 배출 발생
# 원인 발생
# 인위 발생
# 자연 발생
# 구분 발생
# 발생 인위
# 원인 인위
# 중국 인위
# 발 인위
# 미세먼지 인위
# 공장 인위
# 매연 인위
# 쓰레기 인위
# 소각 인위
# 항만 인위
# 지역 인위
# 가정 인위
# 생선 인위
# 그 인위
# 외 인위
# 것 인위
# 구울 인위
# 때 인위
# 등 인위
# 국가 발생
# 중국 발생
# 한국 발생
# 중국 발생
# 경우 발생
# 세계 발생
# 화석 발생
# 연료 발생
# 가장 발생
# 소비 발생
# 나라 발생
# 손 발생
# 베이징시 발생
# 톈진시 발생
# 칭다오시 발생
# 등 발생
# 동부 발생
# 지역 발생
# 고비 발생
# 사막 발생
# 인접 발생
# 곳도 발생
# 역시 발생
# 미세먼지 발생
# 범 발생
# 등 발생
# 아시아 발생
# 최대 발생
# 미세먼지 발생
# 원인 발생
# 공국 발생
# 손 발생
# 미세먼지 다만
# 주로 다만
# 건기 다만
# 겨울 다만
# 가장 다만
# 발생 다만
# 한반도 다만
# 북한 다만
# 전 다만
# 지역 다만
# 대한민국 다만
# 새만금 다만
# 이북 다만
# 지역 다만
# 중 다만
# 간지 다만
# 영향 다만
# 강원도 다만
# 영동 다만
# 지방 다만
# 경상북도 다만
# 북부 다만
# 동해안 다만
# 울릉도 다만
# 독도 다만
# 제외 다만
# 중부 다만
# 전 다만
# 지역 다만
# 남부 다만
# 일부 다만
# 지역 다만
# 발생 다만
# 경우 일본
# 미세먼지 일본
# 규슈 일본
# 이키 일본
# 섬 일본
# 쓰시마섬 일본
# 등지 일본
# 간 일본
# 적 일본
# 발생 일본
# 경우 일본
# 것 일본
# 중국 우리나라
# 미세먼지 우리나라
# 피해 우리나라
# 러시아 우리나라
# 러시아 우리나라
# 체적 우리나라
# 미세먼지 우리나라
# 발생량 우리나라
# 지역 우리나라
# 편차 우리나라
# 지역 연해주
# 경우 연해주
# 동풍 연해주
# 타고 연해주
# 미세먼지 연해주
# 유입 연해주
# 일 연해주
# 한반도 연해주
# 달리 연해주
# 덜 연해주
# 것 연해주
# 구성 미세먼지
# 성분 미세먼지
# 구성 미세먼지
# 성분 미세먼지
# 질산염 미세먼지
# 황산염 미세먼지
# 등 미세먼지
# 노인 질병
# 사망률 질병
# 증가 질병
# 국립 질병
# 환경과학 질병
# 인하대 질병
# 팀 질병
# 미세먼지 질병
# 사망률 질병
# 연구 질병
# 결과 질병
# 서울 질병
# 미세먼지 질병
# 농도 질병
# 당 질병
# 증가 질병
# 때 질병
# 살 질병
# 이상 질병
# 노인 질병
# 등 질병
# 대기오염 질병
# 집단 질병
# 사망률 질병
# 태아 임산부
# 이화여대 임산부
# 의대 임산부
# 하은 임산부
# 교수 임산부
# 팀 임산부
# 연구 임산부
# 결과 임산부
# 미세먼지 임산부
# 농도 임산부
# 저체중 임산부
# 출산 임산부
# 위험 임산부
# 부산 양산
# 병원 양산
# 산업의학 양산
# 전문의 양산
# 대기과학 양산
# 및 양산
# 지리 양산
# 정보 양산
# 시스템 양산
# 전문가 양산
# 공동 양산
# 연구 양산
# 진행 양산
# 결과 양산
# 미세먼지 양산
# 직경 양산
# 이하 양산
# 먼지 양산
# 농도 양산
# 저체중 양산
# 출산 양산
# 및 양산
# 사산 양산
# 기형 양산
# 발생 양산
# 관계 양산
# 것 양산
# 조사 양산
# 파크 카라칼
# 지역 카라칼
# 먼지 카라칼
# 호흡기 카라칼
# 질환 카라칼
# 상관관계 카라칼
# 조사 카라칼
# 건강 카라칼
# 위협 카라칼
# 미세먼지 카라칼
# 전체 카라칼
# 먼지 카라칼
# 가운데 카라칼
# 것 카라칼
# 이 카라칼
# 지역 카라칼
# 어린이 카라칼
# 폐활량 카라칼
# 등 카라칼
# 폐기 카라칼
# 능이 카라칼
# 유럽 카라칼
# 어린이 카라칼
# 현저 카라칼
# 것 카라칼
# 대학병원 미국
# 아동 미국
# 천 미국
# 백 미국
# 명 미국
# 조사 미국
# 연구 미국
# 미세먼지 미국
# 농도 미국
# 지역 미국
# 아이 미국
# 지역 미국
# 아이 미국
# 폐활량 미국
# 정상 미국
# 못 미국
# 폐 미국
# 기능 미국
# 장애 미국
# 를 미국
# 가능성 미국
# 것 미국
# 조사 미국
# 때문 사실
# 전문가 사실
# 미세먼지 사실
# 살인자 사실
# 사람 천식
# 폐포 천식
# 침투 천식
# 기관지 천식
# 폐 천식
# 미세먼지 천식
# 각종 천식
# 호흡기 천식
# 질환 천식
# 직접 천식
# 원인 천식
# 몸 천식
# 면역 천식
# 기능 천식
# 여성 또한
# 사망원인 또한
# 조리 또한
# 과정 또한
# 발생 또한
# 미세먼지 또한
# 사망 또한
# 환경 한국
# 정책 한국
# 평가 한국
# 연구원 한국
# 승헌 한국
# 박사 한국
# 팀 한국
# 결과 한국
# 미세먼지 한국
# 감축 한국
# 수도권 한국
# 관련 한국
# 질환 한국
# 사망자 한국
# 수가 한국
# 명 한국
# 심장 한국
# 및 한국
# 호흡기 한국
# 질환 한국
# 건수 한국
# 연간 한국
# 건 한국
# 수 한국
# 것 한국
# 전망 한국
# 심장 또
# 및 또
# 호흡기 또
# 계통 또
# 질환 또
# 관련 또
# 의료 또
# 비용 또
# 등 또
# 토대 또
# 미세먼지 또
# 감축 또
# 이익 또
# 계산 또
# 결과 또
# 연간 또
# 것 또
# 풀이 또
# 무연탄 두통
# 때 두통
# 신경계 두통
# 독성 두통
# 물질 두통
# 납 두통
# 비소 두통
# 아연 두통
# 등 두통
# 유해 두통
# 중금속 두통
# 농도 두통
# 미세먼지 두통
# 사람 두통
# 기침 두통
# 목 두통
# 피부 두통
# 트러블 두통
# 기도 두통
# 미세먼지 대부분
# 치명 대부분
# 중 대부분
# 황산 대부분
# 이온 대부분
# 질산 대부분
# 이온 대부분
# 등 대부분
# 황사 대부분
# 속 대부분
# 먼지 대부분
# 흡착 대부분
# 산화물 대부분
# 호흡 대부분
# 폐 대부분
# 모공 아토피
# 더 아토피
# 초미세먼지 아토피
# 모공 아토피
# 침투 아토피
# 등 아토피
# 피부염 아토피
# 원인 아토피
# 때문 아토피
# 여드름 아토피
# 사람 아토피
# 역시 아토피
# 황사 아토피
# 예보 아토피
# 야외 아토피
# 활동 아토피
# 자제 아토피
# 것 아토피
# 저항 인슐린
# 대기오염 인슐린
# 미세먼지 인슐린
# 주성분 인슐린
# 노년 인슐린
# 여성 인슐린
# 저항 인슐린
# 연구 인슐린
# 결과 인슐린
# 대책 예방
# 사전 예방
# 미세먼지 예방
# 농도 예방
# 확인 예방
# 후 예방
# 농도 예방
# 활동 예방
# 범위 예방
# 정 예방
# 로부터 미세먼지
# 보호 미세먼지
# 수 미세먼지
# 가장 미세먼지
# 보편 미세먼지
# 방법 미세먼지
# 차단 미세먼지
# 마스크 미세먼지
# 착용 미세먼지
# 것 미세먼지
# 차단 미세먼지
# 성능 미세먼지
# 마스크 미세먼지
# 제품 미세먼지
# 포장 미세먼지
# 의약외품 미세먼지
# 문자 미세먼지
# 등 미세먼지
# 표시 미세먼지
# 링크 외부
# 위키미디어 외부
# 공용 외부
# 미세먼지 외부
# 관련 외부
# 미디어 외부
# 분류 외부

# %%
i=0
for each_line in text2:
#for i in range (len(nouns1)):
    if each_line.find(nouns2[i])>0:
        nlpy4 = Twitter()
        nouns4 = nlpy4.nouns(each_line)
        G1.add_nodes_from(nouns4)
        for j in range (len(nouns4)):
            for l in range (len(nouns4)):
                if nouns4[j]!=nouns4[i]:
                    print(nouns4[j],nouns4[i])
                    G1.add_edges_from([(nouns4[j],nouns4[i])])
                    G1.add_edges_from([(nouns4[i],nouns4[j])])
                    break
# Out:
# 스모그 형태
# 바람 형태
# 기온역전 형태
# 기상 형태
# 상태 형태
# 발생 형태
# 기상 기온역전
# 조건 기온역전
# 스모그 기온역전
# 높이 기온역전
# 것 기온역전
# 도시 기온역전
# 근처 기온역전
# 산맥 기온역전
# 스모그 기온역전
# 데 기온역전
# 한몫 기온역전
# 피해 스모그
# 미국 스모그
# 펜실베이니아주 스모그
# 도 스모그
# 발생 스모그
# 광화학 스모그
# 여 스모그
# 명 스모그
# 사망 스모그
# 명 스모그
# 가량 스모그
# 병 스모그
# 런던 영국
# 발생 영국
# 스모그 영국
# 집중 영국
# 현상 영국
# 동안 영국
# 약 영국
# 명 영국
# 사망 영국
# 식물 스모그
# 죽 스모그
# 건축 스모그
# 재의 스모그
# 부식 스모그
# 진행 스모그
# 스모그 서울
# 주로 서울
# 미세먼지 서울
# 오염 서울
# 대기 서울
# 습도 서울
# 바람 서울
# 날 서울
# 발생 서울
# 발생 스모그
# 하늘 스모그
# 볼 스모그
# 수 스모그
# 거리 스모그
# 대기오염 스모그
# 봄 겨울
# 난방 겨울
# 산업 겨울
# 연료 겨울
# 연소 겨울
# 중 겨울
# 황산 겨울
# 화물 겨울
# 먼지 겨울
# 때문 겨울
# 스모그 겨울
# 발생 겨울
# 여름 겨울
# 자동차 겨울
# 질소 겨울
# 산화물 겨울
# 탄화수소 겨울
# 광화학 겨울
# 반응 겨울
# 스모그 겨울
# 발생 겨울
# 주요 스모그
# 원인 스모그
# 미세먼지 스모그
# 연료 스모그
# 연소 스모그
# 과정 스모그
# 발생 스모그
# 성분 스모그
# 자동차 스모그
# 발생 스모그
# 성분 스모그
# 스모그 런던
# 황화 런던
# 스모그 런던
# 화석연료 런던
# 이산화황 런던
# 일산화탄소 런던
# 때문 런던
# 스모그 형
# 광화학 형
# 스모그 형
# 자동차 형
# 배기 형
# 가스 형
# 질소 형
# 산화물 형
# 스모그 화산
# 자연 화산
# 스모그 화산
# 폭발 화산
# 분출 화산
# 이산화황 화산
# 때문 화산
# 스모그 혼합형
# 서울 혼합형
# 스모그 혼합형
# 런던 혼합형
# 스모그 혼합형
# 형 혼합형
# 스모그 혼합형
# 현상 혼합형
# 스모그 종류
# 크게 종류
# 형 종류
# 스모그 종류
# 런던 종류
# 스모그 종류
# 스모그 원래
# 석탄 원래
# 연소 원래
# 데 원래
# 여러 원래
# 가지 원래
# 결과물 원래
# 안개 원래
# 회색 원래
# 안개 원래
# 식 원래
# 발생 원래
# 것 원래
# 달리 원래
# 광화학 원래
# 스모그 원래
# 자동차 원래
# 배기가스 원래
# 석유 원래
# 연료 원래
# 연소 원래
# 후 원래
# 이후 원래
# 빛 원래
# 화학반응 원래
# 과정 원래
# 통해 원래
# 생물 원래
# 화합물 원래
# 황 원래
# 갈색 원래
# 안개 원래
# 스모그 광화학
# 미국 광화학
# 로스엔젤레스 광화학
# 처음 광화학
# 발생 광화학
# 확인 광화학
# 때문 광화학
# 과거 광화학
# 스모그 광화학
# 런던 광화학
# 스모그 광화학
# 스모그 광화학
# 로스앤젤레스 광화학
# 스모그 광화학
# 기도 광화학
# 스모그 형
# 광화학 형
# 스모그 형
# 로스앤젤레스 형
# 스모그 형
# 주로 형
# 자동차 형
# 배기가스 형
# 속 형
# 함유 형
# 올레 형
# 탄화수소 형
# 질소 형
# 산화물 형
# 혼합물 형
# 태양 형
# 광선 형
# 작용 형
# 광화학 형
# 반응 형
# 것 형
# 광화학 형
# 스모그 형
# 고도 형
# 스모그 런던
# 황화 런던
# 스모그 런던
# 주로 런던
# 공장 런던
# 및 런던
# 빌딩 런던
# 시설 런던
# 일반 런던
# 가정 런던
# 난방 런던
# 시설 런던
# 등 런던
# 배출 런던
# 아황산가스 런던
# 매연 런던
# 직접 런던
# 굴뚝 런던
# 오염 런던
# 물질 런던
# 발생 런던
# 스모그 런던
# 상황 피해
# 배출 피해
# 연기 피해
# 안개 피해
# 스모그 피해
# 형성 피해
# 연기 피해
# 속 피해
# 아황산가스 피해
# 황산 피해
# 안개 피해
# 스모그 광화학
# 경우 광화학
# 인체 광화학
# 영향 광화학
# 주로 광화학
# 눈 광화학
# 톨루엔 벤젠
# 등 벤젠
# 햇빛 벤젠
# 등 벤젠
# 반응 벤젠
# 광화학 벤젠
# 스모그 벤젠
# 장기간 벤젠
# 인체 벤젠
# 노 벤젠
# 출시 벤젠
# 백혈병 벤젠
# 암 벤젠
# 등 벤젠
# 유발 벤젠
# 수 벤젠
# 스모그 런던
# 사건 런던
# 사건 런던
# 발생 런던
# 후 런던
# 첫 런던
# 주 런던
# 동안 런던
# 호흡 런던
# 장애 런던
# 질식 런던
# 등 런던
# 여명 런던
# 시민 런던
# 사망 런던
# 그 런던
# 후 런던
# 만성 런던
# 폐 런던
# 질환 런던
# 명 런던
# 추가 런던
# 사망 런던
# 총 런던
# 명 런던
# 동안 런던
# 대기오염 런던
# 현상 런던
# 생명 런던
# 시티 멕시코
# 스모그 멕시코
# 도시 멕시코
# 차량 멕시코
# 배기가스 멕시코
# 매연 멕시코
# 분진 멕시코
# 오존 멕시코
# 불량 멕시코
# 지수 멕시코
# 생활환경 멕시코
# 위험 멕시코
# 지표 멕시코
# 배 멕시코
# 초과 멕시코
# 스모그 서울
# 우려 서울
# 광화학 서울
# 스모그 서울
# 햇빛 서울
# 자외선 서울
# 차량 서울
# 오염 서울
# 물질 서울
# 맑은 서울
# 날 서울
# 안개 서울
# 것 서울
# 상태 서울
# 시정 서울
# 장애 서울
# 연 서울
# 발생 서울
# 오존층 보기
# 산성비 보기
# 황사 보기
# 각주 보기
# 출처 보기
# 및 보기
# 외부 보기
# 링크 보기
# 조윤승 보기
# 스모그 보기
# 건강 보기
# 피해 보기
# 런던 보기
# 스모그 보기
# 참사 보기
# 재 보기
# 조명 보기
# 환경 보기
# 위생 보기
# 학회 보기
# 고교생 인호
# 화학 인호
# 스페셜 인호
# 화사 인호
# 중국 인호
# 스모그 인호
# 피해 인호
# 스모그 베이징
# 잡기 베이징
# 국어사전 네이버
# 스모그 네이버
# 두산 네이버
# 백과사전 네이버
# 스모그 네이버
# 두산 네이버
# 백과사전 네이버
# 탈황 네이버
# 두산 네이버
# 백과사전 네이버
# 전기 네이버

# %%
degree=dict(G.degree)
nx.draw(G,font_family=font_name, font_size=9,node_size=[v * 10 for v in degree.values()],with_labels=True)
#plt.figure(figsize=(100,100))
plt.savefig("Graph.png", format="PNG")
plt.show()

# %%
degree1=dict(G1.degree)
nx.draw(G1,font_family=font_name, font_size=9,node_size=[v * 10 for v in degree1.values()],with_labels=True)
#plt.figure(figsize=(100,100))
plt.savefig("Graph1.png", format="PNG")
plt.show()

# %%
degree1
# Out:
# {'형태': 12,
#  '스모그': 94,
#  '바람': 4,
#  '기온역전': 22,
#  '기상': 4,
#  '상태': 4,
#  '발생': 16,
#  '조건': 2,
#  '높이': 2,
#  '것': 8,
#  '도시': 4,
#  '근처': 2,
#  '산맥': 2,
#  '데': 4,
#  '한몫': 2,
#  '피해': 22,
#  '미국': 4,
#  '펜실베이니아주': 2,
#  '도': 2,
#  '광화학': 42,
#  '여': 2,
#  '명': 6,
#  '사망': 6,
#  '가량': 2,
#  '병': 2,
#  '영국': 18,
#  '런던': 98,
#  '집중': 2,
#  '현상': 6,
#  '동안': 4,
#  '약': 2,
#  '식물': 2,
#  '죽': 2,
#  '건축': 2,
#  '재의': 2,
#  '부식': 2,
#  '진행': 2,
#  '서울': 46,
#  '주로': 8,
#  '미세먼지': 4,
#  '오염': 4,
#  '대기': 2,
#  '습도': 2,
#  '날': 2,
#  '하늘': 2,
#  '볼': 2,
#  '수': 4,
#  '거리': 2,
#  '대기오염': 4,
#  '겨울': 38,
#  '봄': 2,
#  '난방': 4,
#  '산업': 2,
#  '연료': 6,
#  '연소': 6,
#  '중': 2,
#  '황산': 4,
#  '화물': 2,
#  '먼지': 2,
#  '때문': 8,
#  '여름': 2,
#  '자동차': 8,
#  '질소': 4,
#  '산화물': 4,
#  '탄화수소': 4,
#  '반응': 6,
#  '주요': 2,
#  '원인': 2,
#  '과정': 4,
#  '성분': 2,
#  '황화': 2,
#  '화석연료': 2,
#  '이산화황': 4,
#  '일산화탄소': 2,
#  '형': 46,
#  '배기': 2,
#  '가스': 2,
#  '화산': 12,
#  '자연': 2,
#  '폭발': 2,
#  '분출': 2,
#  '혼합형': 10,
#  '종류': 8,
#  '크게': 2,
#  '원래': 56,
#  '석탄': 2,
#  '여러': 2,
#  '가지': 2,
#  '결과물': 2,
#  '안개': 6,
#  '회색': 2,
#  '식': 2,
#  '달리': 2,
#  '배기가스': 6,
#  '석유': 2,
#  '후': 4,
#  '이후': 2,
#  '빛': 2,
#  '화학반응': 2,
#  '통해': 2,
#  '생물': 2,
#  '화합물': 2,
#  '황': 2,
#  '갈색': 2,
#  '로스엔젤레스': 2,
#  '처음': 2,
#  '확인': 2,
#  '과거': 2,
#  '로스앤젤레스': 4,
#  '기도': 2,
#  '속': 4,
#  '함유': 2,
#  '올레': 2,
#  '혼합물': 2,
#  '태양': 2,
#  '광선': 2,
#  '작용': 2,
#  '고도': 2,
#  '공장': 2,
#  '및': 4,
#  '빌딩': 2,
#  '시설': 2,
#  '일반': 2,
#  '가정': 2,
#  '등': 4,
#  '배출': 4,
#  '아황산가스': 4,
#  '매연': 4,
#  '직접': 2,
#  '굴뚝': 2,
#  '물질': 4,
#  '상황': 2,
#  '연기': 2,
#  '형성': 2,
#  '경우': 2,
#  '인체': 4,
#  '영향': 2,
#  '눈': 2,
#  '벤젠': 28,
#  '톨루엔': 2,
#  '햇빛': 4,
#  '장기간': 2,
#  '노': 2,
#  '출시': 2,
#  '백혈병': 2,
#  '암': 2,
#  '유발': 2,
#  '사건': 2,
#  '첫': 2,
#  '주': 2,
#  '호흡': 2,
#  '장애': 4,
#  '질식': 2,
#  '여명': 2,
#  '시민': 2,
#  '그': 2,
#  '만성': 2,
#  '폐': 2,
#  '질환': 2,
#  '추가': 2,
#  '총': 2,
#  '생명': 2,
#  '멕시코': 30,
#  '시티': 2,
#  '차량': 4,
#  '분진': 2,
#  '오존': 2,
#  '불량': 2,
#  '지수': 2,
#  '생활환경': 2,
#  '위험': 2,
#  '지표': 2,
#  '배': 2,
#  '초과': 2,
#  '우려': 2,
#  '자외선': 2,
#  '맑은': 2,
#  '시정': 2,
#  '연': 2,
#  '보기': 38,
#  '오존층': 2,
#  '산성비': 2,
#  '황사': 2,
#  '각주': 2,
#  '출처': 2,
#  '외부': 2,
#  '링크': 2,
#  '조윤승': 2,
#  '건강': 2,
#  '참사': 2,
#  '재': 2,
#  '조명': 2,
#  '환경': 2,
#  '위생': 2,
#  '학회': 2,
#  '인호': 14,
#  '고교생': 2,
#  '화학': 2,
#  '스페셜': 2,
#  '화사': 2,
#  '중국': 2,
#  '베이징': 4,
#  '잡기': 2,
#  '네이버': 12,
#  '국어사전': 2,
#  '두산': 2,
#  '백과사전': 2,
#  '탈황': 2,
#  '전기': 2}

# %%
G=nx.DiGraph()
G1=nx.DiGraph()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
import string
# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='NanumGothic') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
text1=[]
text1=p_wiki1.text.split(".")

# %%
text2=[]
text2=p_wiki2.text.split(".")

# %%
i=0
for each_line in text1:
#for i in range (len(nouns1)):
    if each_line.find(nouns1[i])>0:
        nlpy3 = Twitter()
        nouns3 = nlpy3.nouns(each_line)
        print(nouns3)
# Out:
# ['초미세먼지', '미세먼지']
# ['미세먼지', '부유', '분진', '입자', '물질', '등', '불리', '명칭', '약간', '다른', '의미', '가지']
# ['미국', '펜실베이니아주', '도', '명', '사망', '대기오염', '사고', '약', '명의', '사망자', '발생', '런던', '스모그', '미세먼지', '인체', '영향', '대표', '사례']
# ['그', '이후', '미세먼지', '인체', '영향', '대한', '역학', '조사', '실시', '이하', '미세먼지', '입자', '취약', '집단', '질병', '발생', '률', '사망률', '등', '인체', '영향', '가능성', '것']
# ['이후', '각', '국', '대기오염', '대책', '마련', '미세먼지', '인체', '환경', '영향', '위해', '대기오염', '기준', '마련']
# ['미세먼지', '입자', '크기', '이하', '먼지', '입자', '크기', '매우', '미세먼지', '구분']
# ['미세먼지', '지름', '미세먼지', '지름']
# ['미세먼지']
# ['것', '초미세먼지']
# ['발생', '원인', '미세먼지', '배출', '원인', '인위', '발생', '자연', '발생', '구분']
# ['인위', '발생', '원인', '중국', '발', '미세먼지', '공장', '매연', '쓰레기', '소각', '항만', '지역', '가정', '생선', '그', '외', '것', '구울', '때', '등']
# ['발생', '국가', '중국', '한국', '중국', '경우', '세계', '화석', '연료', '가장', '소비', '나라', '손', '베이징시', '톈진시', '칭다오시', '등', '동부', '지역', '고비', '사막', '인접', '곳도', '역시', '미세먼지', '범', '등', '아시아', '최대', '미세먼지', '발생', '원인', '공국', '손']
# ['다만', '미세먼지', '주로', '건기', '겨울', '가장', '발생', '한반도', '북한', '전', '지역', '대한민국', '새만금', '이북', '지역', '중', '간지', '영향', '강원도', '영동', '지방', '경상북도', '북부', '동해안', '울릉도', '독도', '제외', '중부', '전', '지역', '남부', '일부', '지역', '발생']
# ['일본', '경우', '미세먼지', '규슈', '이키', '섬', '쓰시마섬', '등지', '간', '적', '발생', '경우', '것']
# ['우리나라', '중국', '미세먼지', '피해', '러시아', '러시아', '체적', '미세먼지', '발생량', '지역', '편차']
# ['연해주', '지역', '경우', '동풍', '타고', '미세먼지', '유입', '일', '한반도', '달리', '덜', '것']
# ['미세먼지', '구성', '성분', '미세먼지', '구성', '성분', '질산염', '황산염', '등']
# ['질병', '노인', '사망률', '증가', '국립', '환경과학', '인하대', '팀', '미세먼지', '사망률', '연구', '결과', '서울', '미세먼지', '농도', '당', '증가', '때', '살', '이상', '노인', '등', '대기오염', '집단', '사망률']
# ['초미세먼지']
# ['임산부', '태아', '이화여대', '의대', '하은', '교수', '팀', '연구', '결과', '미세먼지', '농도', '저체중', '출산', '위험']
# ['양산', '부산', '병원', '산업의학', '전문의', '대기과학', '및', '지리', '정보', '시스템', '전문가', '공동', '연구', '진행', '결과', '미세먼지', '직경', '이하', '먼지', '농도', '저체중', '출산', '및', '사산', '기형', '발생', '관계', '것', '조사']
# ['카라칼', '파크', '지역', '먼지', '호흡기', '질환', '상관관계', '조사', '건강', '위협', '미세먼지', '전체', '먼지', '가운데', '것', '이', '지역', '어린이', '폐활량', '등', '폐기', '능이', '유럽', '어린이', '현저', '것']
# ['미국', '대학병원', '아동', '천', '백', '명', '조사', '연구', '미세먼지', '농도', '지역', '아이', '지역', '아이', '폐활량', '정상', '못', '폐', '기능', '장애', '를', '가능성', '것', '조사']
# ['사실', '때문', '전문가', '미세먼지', '살인자']
# ['천식', '사람', '폐포', '침투', '기관지', '폐', '미세먼지', '각종', '호흡기', '질환', '직접', '원인', '몸', '면역', '기능']
# ['또한', '여성', '사망원인', '조리', '과정', '발생', '미세먼지', '사망']
# ['한국', '환경', '정책', '평가', '연구원', '승헌', '박사', '팀', '결과', '미세먼지', '감축', '수도권', '관련', '질환', '사망자', '수가', '명', '심장', '및', '호흡기', '질환', '건수', '연간', '건', '수', '것', '전망']
# ['또', '심장', '및', '호흡기', '계통', '질환', '관련', '의료', '비용', '등', '토대', '미세먼지', '감축', '이익', '계산', '결과', '연간', '것', '풀이']
# ['두통', '무연탄', '때', '신경계', '독성', '물질', '납', '비소', '아연', '등', '유해', '중금속', '농도', '미세먼지', '사람', '기침', '목', '피부', '트러블', '기도']
# ['대부분', '미세먼지', '치명', '중', '황산', '이온', '질산', '이온', '등', '황사', '속', '먼지', '흡착', '산화물', '호흡', '폐']
# ['아토피', '모공', '더', '초미세먼지', '모공', '침투', '아토피', '등', '피부염', '원인', '때문', '여드름', '아토피', '사람', '역시', '황사', '예보', '야외', '활동', '자제', '것']
# ['인슐린', '저항', '대기오염', '미세먼지', '주성분', '노년', '여성', '인슐린', '저항', '연구', '결과']
# ['예방', '대책', '사전', '미세먼지', '농도', '확인', '후', '농도', '활동', '범위', '정']
# ['미세먼지', '로부터', '보호', '수', '가장', '보편', '방법', '미세먼지', '차단', '마스크', '착용', '것']
# ['미세먼지', '차단', '성능', '마스크', '제품', '포장', '의약외품', '문자', '등', '표시']
# ['외부', '링크', '위키미디어', '공용', '미세먼지', '관련', '미디어', '분류']

# %%
i=0
for each_line in text2:
#for i in range (len(nouns1)):
    if each_line.find(nouns2[i])>0:
        nlpy4 = Twitter()
        nouns4 = nlpy4.nouns(each_line)
        print(nouns4)
# Out:
# ['형태', '스모그', '바람', '기온역전', '기상', '상태', '발생']
# ['기온역전', '기상', '조건', '스모그', '높이', '것', '도시', '근처', '산맥', '스모그', '데', '한몫']
# ['스모그', '피해', '미국', '펜실베이니아주', '도', '발생', '광화학', '스모그', '여', '명', '사망', '명', '가량', '병']
# ['영국', '런던', '발생', '스모그', '집중', '현상', '동안', '약', '명', '사망']
# ['스모그', '식물', '죽', '건축', '재의', '부식', '진행']
# ['서울', '스모그', '주로', '미세먼지', '오염', '대기', '습도', '바람', '날', '발생']
# ['스모그', '발생', '하늘', '볼', '수', '거리', '대기오염']
# ['겨울', '봄', '난방', '산업', '연료', '연소', '중', '황산', '화물', '먼지', '때문', '스모그', '발생', '여름', '자동차', '질소', '산화물', '탄화수소', '광화학', '반응', '스모그', '발생']
# ['스모그', '주요', '원인', '미세먼지', '연료', '연소', '과정', '발생', '성분', '자동차', '발생', '성분']
# ['런던', '스모그', '황화', '스모그', '화석연료', '이산화황', '일산화탄소', '때문']
# ['형', '스모그', '광화학', '스모그', '자동차', '배기', '가스', '질소', '산화물']
# ['화산', '스모그', '자연', '스모그', '화산', '폭발', '분출', '이산화황', '때문']
# ['혼합형', '스모그', '서울', '스모그', '런던', '스모그', '형', '스모그', '현상']
# ['종류', '스모그', '크게', '형', '스모그', '런던', '스모그']
# ['원래', '스모그', '석탄', '연소', '데', '여러', '가지', '결과물', '안개', '회색', '안개', '식', '발생', '것', '달리', '광화학', '스모그', '자동차', '배기가스', '석유', '연료', '연소', '후', '이후', '빛', '화학반응', '과정', '통해', '생물', '화합물', '황', '갈색', '안개']
# ['광화학', '스모그', '미국', '로스엔젤레스', '처음', '발생', '확인', '때문', '과거', '스모그', '런던', '스모그', '광화학', '스모그', '로스앤젤레스', '스모그', '기도']
# ['형', '스모그', '광화학', '스모그', '로스앤젤레스', '스모그', '주로', '자동차', '배기가스', '속', '함유', '올레', '탄화수소', '질소', '산화물', '혼합물', '태양', '광선', '작용', '광화학', '반응', '것', '광화학', '스모그', '고도']
# ['런던', '스모그', '황화', '스모그', '주로', '공장', '및', '빌딩', '시설', '일반', '가정', '난방', '시설', '등', '배출', '아황산가스', '매연', '직접', '굴뚝', '오염', '물질', '발생', '스모그']
# ['피해', '상황', '배출', '연기', '안개', '스모그', '형성', '연기', '속', '아황산가스', '황산', '안개']
# ['광화학', '스모그', '경우', '인체', '영향', '주로', '눈']
# ['벤젠', '톨루엔', '등', '햇빛', '등', '반응', '광화학', '스모그', '장기간', '인체', '노', '출시', '백혈병', '암', '등', '유발', '수']
# ['런던', '스모그', '사건', '사건', '발생', '후', '첫', '주', '동안', '호흡', '장애', '질식', '등', '여명', '시민', '사망', '그', '후', '만성', '폐', '질환', '명', '추가', '사망', '총', '명', '동안', '대기오염', '현상', '생명']
# ['멕시코', '시티', '스모그', '도시', '차량', '배기가스', '매연', '분진', '오존', '불량', '지수', '생활환경', '위험', '지표', '배', '초과']
# ['서울', '스모그', '우려', '광화학', '스모그', '햇빛', '자외선', '차량', '오염', '물질', '맑은', '날', '안개', '것', '상태', '시정', '장애', '연', '발생']
# ['보기', '오존층', '산성비', '황사', '각주', '출처', '및', '외부', '링크', '조윤승', '스모그', '건강', '피해', '런던', '스모그', '참사', '재', '조명', '환경', '위생', '학회']
# ['인호', '고교생', '화학', '스페셜', '화사', '중국', '스모그', '피해']
# ['베이징', '스모그', '잡기']
# ['네이버', '국어사전', '스모그', '네이버', '두산', '백과사전', '스모그', '네이버', '두산', '백과사전', '탈황', '네이버', '두산', '백과사전', '전기']

# %%
i=0
for each_line in text1:
#for i in range (len(nouns1)):
    if each_line.find(nouns1[i])>0:
        nlpy3 = Twitter()
        nouns3 = nlpy3.nouns(each_line)
        G.add_nodes_from(nouns3)
        for j in range (len(nouns3)):
            for l in range (len(nouns3)):
                if nouns3[j]!=nouns3[i]:
                    print(nouns3[j],nouns3[i])
                    G.add_edges_from([(nouns3[j],nouns3[i])])
                    G.add_edges_from([(nouns3[i],nouns3[j])])
                    break
# Out:
# 미세먼지 초미세먼지
# 부유 미세먼지
# 분진 미세먼지
# 입자 미세먼지
# 물질 미세먼지
# 등 미세먼지
# 불리 미세먼지
# 명칭 미세먼지
# 약간 미세먼지
# 다른 미세먼지
# 의미 미세먼지
# 가지 미세먼지
# 펜실베이니아주 미국
# 도 미국
# 명 미국
# 사망 미국
# 대기오염 미국
# 사고 미국
# 약 미국
# 명의 미국
# 사망자 미국
# 발생 미국
# 런던 미국
# 스모그 미국
# 미세먼지 미국
# 인체 미국
# 영향 미국
# 대표 미국
# 사례 미국
# 이후 그
# 미세먼지 그
# 인체 그
# 영향 그
# 대한 그
# 역학 그
# 조사 그
# 실시 그
# 이하 그
# 미세먼지 그
# 입자 그
# 취약 그
# 집단 그
# 질병 그
# 발생 그
# 률 그
# 사망률 그
# 등 그
# 인체 그
# 영향 그
# 가능성 그
# 것 그
# 각 이후
# 국 이후
# 대기오염 이후
# 대책 이후
# 마련 이후
# 미세먼지 이후
# 인체 이후
# 환경 이후
# 영향 이후
# 위해 이후
# 대기오염 이후
# 기준 이후
# 마련 이후
# 입자 미세먼지
# 크기 미세먼지
# 이하 미세먼지
# 먼지 미세먼지
# 입자 미세먼지
# 크기 미세먼지
# 매우 미세먼지
# 구분 미세먼지
# 지름 미세먼지
# 지름 미세먼지
# 초미세먼지 것
# 원인 발생
# 미세먼지 발생
# 배출 발생
# 원인 발생
# 인위 발생
# 자연 발생
# 구분 발생
# 발생 인위
# 원인 인위
# 중국 인위
# 발 인위
# 미세먼지 인위
# 공장 인위
# 매연 인위
# 쓰레기 인위
# 소각 인위
# 항만 인위
# 지역 인위
# 가정 인위
# 생선 인위
# 그 인위
# 외 인위
# 것 인위
# 구울 인위
# 때 인위
# 등 인위
# 국가 발생
# 중국 발생
# 한국 발생
# 중국 발생
# 경우 발생
# 세계 발생
# 화석 발생
# 연료 발생
# 가장 발생
# 소비 발생
# 나라 발생
# 손 발생
# 베이징시 발생
# 톈진시 발생
# 칭다오시 발생
# 등 발생
# 동부 발생
# 지역 발생
# 고비 발생
# 사막 발생
# 인접 발생
# 곳도 발생
# 역시 발생
# 미세먼지 발생
# 범 발생
# 등 발생
# 아시아 발생
# 최대 발생
# 미세먼지 발생
# 원인 발생
# 공국 발생
# 손 발생
# 미세먼지 다만
# 주로 다만
# 건기 다만
# 겨울 다만
# 가장 다만
# 발생 다만
# 한반도 다만
# 북한 다만
# 전 다만
# 지역 다만
# 대한민국 다만
# 새만금 다만
# 이북 다만
# 지역 다만
# 중 다만
# 간지 다만
# 영향 다만
# 강원도 다만
# 영동 다만
# 지방 다만
# 경상북도 다만
# 북부 다만
# 동해안 다만
# 울릉도 다만
# 독도 다만
# 제외 다만
# 중부 다만
# 전 다만
# 지역 다만
# 남부 다만
# 일부 다만
# 지역 다만
# 발생 다만
# 경우 일본
# 미세먼지 일본
# 규슈 일본
# 이키 일본
# 섬 일본
# 쓰시마섬 일본
# 등지 일본
# 간 일본
# 적 일본
# 발생 일본
# 경우 일본
# 것 일본
# 중국 우리나라
# 미세먼지 우리나라
# 피해 우리나라
# 러시아 우리나라
# 러시아 우리나라
# 체적 우리나라
# 미세먼지 우리나라
# 발생량 우리나라
# 지역 우리나라
# 편차 우리나라
# 지역 연해주
# 경우 연해주
# 동풍 연해주
# 타고 연해주
# 미세먼지 연해주
# 유입 연해주
# 일 연해주
# 한반도 연해주
# 달리 연해주
# 덜 연해주
# 것 연해주
# 구성 미세먼지
# 성분 미세먼지
# 구성 미세먼지
# 성분 미세먼지
# 질산염 미세먼지
# 황산염 미세먼지
# 등 미세먼지
# 노인 질병
# 사망률 질병
# 증가 질병
# 국립 질병
# 환경과학 질병
# 인하대 질병
# 팀 질병
# 미세먼지 질병
# 사망률 질병
# 연구 질병
# 결과 질병
# 서울 질병
# 미세먼지 질병
# 농도 질병
# 당 질병
# 증가 질병
# 때 질병
# 살 질병
# 이상 질병
# 노인 질병
# 등 질병
# 대기오염 질병
# 집단 질병
# 사망률 질병
# 태아 임산부
# 이화여대 임산부
# 의대 임산부
# 하은 임산부
# 교수 임산부
# 팀 임산부
# 연구 임산부
# 결과 임산부
# 미세먼지 임산부
# 농도 임산부
# 저체중 임산부
# 출산 임산부
# 위험 임산부
# 부산 양산
# 병원 양산
# 산업의학 양산
# 전문의 양산
# 대기과학 양산
# 및 양산
# 지리 양산
# 정보 양산
# 시스템 양산
# 전문가 양산
# 공동 양산
# 연구 양산
# 진행 양산
# 결과 양산
# 미세먼지 양산
# 직경 양산
# 이하 양산
# 먼지 양산
# 농도 양산
# 저체중 양산
# 출산 양산
# 및 양산
# 사산 양산
# 기형 양산
# 발생 양산
# 관계 양산
# 것 양산
# 조사 양산
# 파크 카라칼
# 지역 카라칼
# 먼지 카라칼
# 호흡기 카라칼
# 질환 카라칼
# 상관관계 카라칼
# 조사 카라칼
# 건강 카라칼
# 위협 카라칼
# 미세먼지 카라칼
# 전체 카라칼
# 먼지 카라칼
# 가운데 카라칼
# 것 카라칼
# 이 카라칼
# 지역 카라칼
# 어린이 카라칼
# 폐활량 카라칼
# 등 카라칼
# 폐기 카라칼
# 능이 카라칼
# 유럽 카라칼
# 어린이 카라칼
# 현저 카라칼
# 것 카라칼
# 대학병원 미국
# 아동 미국
# 천 미국
# 백 미국
# 명 미국
# 조사 미국
# 연구 미국
# 미세먼지 미국
# 농도 미국
# 지역 미국
# 아이 미국
# 지역 미국
# 아이 미국
# 폐활량 미국
# 정상 미국
# 못 미국
# 폐 미국
# 기능 미국
# 장애 미국
# 를 미국
# 가능성 미국
# 것 미국
# 조사 미국
# 때문 사실
# 전문가 사실
# 미세먼지 사실
# 살인자 사실
# 사람 천식
# 폐포 천식
# 침투 천식
# 기관지 천식
# 폐 천식
# 미세먼지 천식
# 각종 천식
# 호흡기 천식
# 질환 천식
# 직접 천식
# 원인 천식
# 몸 천식
# 면역 천식
# 기능 천식
# 여성 또한
# 사망원인 또한
# 조리 또한
# 과정 또한
# 발생 또한
# 미세먼지 또한
# 사망 또한
# 환경 한국
# 정책 한국
# 평가 한국
# 연구원 한국
# 승헌 한국
# 박사 한국
# 팀 한국
# 결과 한국
# 미세먼지 한국
# 감축 한국
# 수도권 한국
# 관련 한국
# 질환 한국
# 사망자 한국
# 수가 한국
# 명 한국
# 심장 한국
# 및 한국
# 호흡기 한국
# 질환 한국
# 건수 한국
# 연간 한국
# 건 한국
# 수 한국
# 것 한국
# 전망 한국
# 심장 또
# 및 또
# 호흡기 또
# 계통 또
# 질환 또
# 관련 또
# 의료 또
# 비용 또
# 등 또
# 토대 또
# 미세먼지 또
# 감축 또
# 이익 또
# 계산 또
# 결과 또
# 연간 또
# 것 또
# 풀이 또
# 무연탄 두통
# 때 두통
# 신경계 두통
# 독성 두통
# 물질 두통
# 납 두통
# 비소 두통
# 아연 두통
# 등 두통
# 유해 두통
# 중금속 두통
# 농도 두통
# 미세먼지 두통
# 사람 두통
# 기침 두통
# 목 두통
# 피부 두통
# 트러블 두통
# 기도 두통
# 미세먼지 대부분
# 치명 대부분
# 중 대부분
# 황산 대부분
# 이온 대부분
# 질산 대부분
# 이온 대부분
# 등 대부분
# 황사 대부분
# 속 대부분
# 먼지 대부분
# 흡착 대부분
# 산화물 대부분
# 호흡 대부분
# 폐 대부분
# 모공 아토피
# 더 아토피
# 초미세먼지 아토피
# 모공 아토피
# 침투 아토피
# 등 아토피
# 피부염 아토피
# 원인 아토피
# 때문 아토피
# 여드름 아토피
# 사람 아토피
# 역시 아토피
# 황사 아토피
# 예보 아토피
# 야외 아토피
# 활동 아토피
# 자제 아토피
# 것 아토피
# 저항 인슐린
# 대기오염 인슐린
# 미세먼지 인슐린
# 주성분 인슐린
# 노년 인슐린
# 여성 인슐린
# 저항 인슐린
# 연구 인슐린
# 결과 인슐린
# 대책 예방
# 사전 예방
# 미세먼지 예방
# 농도 예방
# 확인 예방
# 후 예방
# 농도 예방
# 활동 예방
# 범위 예방
# 정 예방
# 로부터 미세먼지
# 보호 미세먼지
# 수 미세먼지
# 가장 미세먼지
# 보편 미세먼지
# 방법 미세먼지
# 차단 미세먼지
# 마스크 미세먼지
# 착용 미세먼지
# 것 미세먼지
# 차단 미세먼지
# 성능 미세먼지
# 마스크 미세먼지
# 제품 미세먼지
# 포장 미세먼지
# 의약외품 미세먼지
# 문자 미세먼지
# 등 미세먼지
# 표시 미세먼지
# 링크 외부
# 위키미디어 외부
# 공용 외부
# 미세먼지 외부
# 관련 외부
# 미디어 외부
# 분류 외부

# %%
i=0
for each_line in text2:
#for i in range (len(nouns1)):
    if each_line.find(nouns2[i])>0:
        nlpy4 = Twitter()
        nouns4 = nlpy4.nouns(each_line)
        G1.add_nodes_from(nouns4)
        for j in range (len(nouns4)):
            for l in range (len(nouns4)):
                if nouns4[j]!=nouns4[i]:
                    print(nouns4[j],nouns4[i])
                    G1.add_edges_from([(nouns4[j],nouns4[i])])
                    G1.add_edges_from([(nouns4[i],nouns4[j])])
                    break
# Out:
# 스모그 형태
# 바람 형태
# 기온역전 형태
# 기상 형태
# 상태 형태
# 발생 형태
# 기상 기온역전
# 조건 기온역전
# 스모그 기온역전
# 높이 기온역전
# 것 기온역전
# 도시 기온역전
# 근처 기온역전
# 산맥 기온역전
# 스모그 기온역전
# 데 기온역전
# 한몫 기온역전
# 피해 스모그
# 미국 스모그
# 펜실베이니아주 스모그
# 도 스모그
# 발생 스모그
# 광화학 스모그
# 여 스모그
# 명 스모그
# 사망 스모그
# 명 스모그
# 가량 스모그
# 병 스모그
# 런던 영국
# 발생 영국
# 스모그 영국
# 집중 영국
# 현상 영국
# 동안 영국
# 약 영국
# 명 영국
# 사망 영국
# 식물 스모그
# 죽 스모그
# 건축 스모그
# 재의 스모그
# 부식 스모그
# 진행 스모그
# 스모그 서울
# 주로 서울
# 미세먼지 서울
# 오염 서울
# 대기 서울
# 습도 서울
# 바람 서울
# 날 서울
# 발생 서울
# 발생 스모그
# 하늘 스모그
# 볼 스모그
# 수 스모그
# 거리 스모그
# 대기오염 스모그
# 봄 겨울
# 난방 겨울
# 산업 겨울
# 연료 겨울
# 연소 겨울
# 중 겨울
# 황산 겨울
# 화물 겨울
# 먼지 겨울
# 때문 겨울
# 스모그 겨울
# 발생 겨울
# 여름 겨울
# 자동차 겨울
# 질소 겨울
# 산화물 겨울
# 탄화수소 겨울
# 광화학 겨울
# 반응 겨울
# 스모그 겨울
# 발생 겨울
# 주요 스모그
# 원인 스모그
# 미세먼지 스모그
# 연료 스모그
# 연소 스모그
# 과정 스모그
# 발생 스모그
# 성분 스모그
# 자동차 스모그
# 발생 스모그
# 성분 스모그
# 스모그 런던
# 황화 런던
# 스모그 런던
# 화석연료 런던
# 이산화황 런던
# 일산화탄소 런던
# 때문 런던
# 스모그 형
# 광화학 형
# 스모그 형
# 자동차 형
# 배기 형
# 가스 형
# 질소 형
# 산화물 형
# 스모그 화산
# 자연 화산
# 스모그 화산
# 폭발 화산
# 분출 화산
# 이산화황 화산
# 때문 화산
# 스모그 혼합형
# 서울 혼합형
# 스모그 혼합형
# 런던 혼합형
# 스모그 혼합형
# 형 혼합형
# 스모그 혼합형
# 현상 혼합형
# 스모그 종류
# 크게 종류
# 형 종류
# 스모그 종류
# 런던 종류
# 스모그 종류
# 스모그 원래
# 석탄 원래
# 연소 원래
# 데 원래
# 여러 원래
# 가지 원래
# 결과물 원래
# 안개 원래
# 회색 원래
# 안개 원래
# 식 원래
# 발생 원래
# 것 원래
# 달리 원래
# 광화학 원래
# 스모그 원래
# 자동차 원래
# 배기가스 원래
# 석유 원래
# 연료 원래
# 연소 원래
# 후 원래
# 이후 원래
# 빛 원래
# 화학반응 원래
# 과정 원래
# 통해 원래
# 생물 원래
# 화합물 원래
# 황 원래
# 갈색 원래
# 안개 원래
# 스모그 광화학
# 미국 광화학
# 로스엔젤레스 광화학
# 처음 광화학
# 발생 광화학
# 확인 광화학
# 때문 광화학
# 과거 광화학
# 스모그 광화학
# 런던 광화학
# 스모그 광화학
# 스모그 광화학
# 로스앤젤레스 광화학
# 스모그 광화학
# 기도 광화학
# 스모그 형
# 광화학 형
# 스모그 형
# 로스앤젤레스 형
# 스모그 형
# 주로 형
# 자동차 형
# 배기가스 형
# 속 형
# 함유 형
# 올레 형
# 탄화수소 형
# 질소 형
# 산화물 형
# 혼합물 형
# 태양 형
# 광선 형
# 작용 형
# 광화학 형
# 반응 형
# 것 형
# 광화학 형
# 스모그 형
# 고도 형
# 스모그 런던
# 황화 런던
# 스모그 런던
# 주로 런던
# 공장 런던
# 및 런던
# 빌딩 런던
# 시설 런던
# 일반 런던
# 가정 런던
# 난방 런던
# 시설 런던
# 등 런던
# 배출 런던
# 아황산가스 런던
# 매연 런던
# 직접 런던
# 굴뚝 런던
# 오염 런던
# 물질 런던
# 발생 런던
# 스모그 런던
# 상황 피해
# 배출 피해
# 연기 피해
# 안개 피해
# 스모그 피해
# 형성 피해
# 연기 피해
# 속 피해
# 아황산가스 피해
# 황산 피해
# 안개 피해
# 스모그 광화학
# 경우 광화학
# 인체 광화학
# 영향 광화학
# 주로 광화학
# 눈 광화학
# 톨루엔 벤젠
# 등 벤젠
# 햇빛 벤젠
# 등 벤젠
# 반응 벤젠
# 광화학 벤젠
# 스모그 벤젠
# 장기간 벤젠
# 인체 벤젠
# 노 벤젠
# 출시 벤젠
# 백혈병 벤젠
# 암 벤젠
# 등 벤젠
# 유발 벤젠
# 수 벤젠
# 스모그 런던
# 사건 런던
# 사건 런던
# 발생 런던
# 후 런던
# 첫 런던
# 주 런던
# 동안 런던
# 호흡 런던
# 장애 런던
# 질식 런던
# 등 런던
# 여명 런던
# 시민 런던
# 사망 런던
# 그 런던
# 후 런던
# 만성 런던
# 폐 런던
# 질환 런던
# 명 런던
# 추가 런던
# 사망 런던
# 총 런던
# 명 런던
# 동안 런던
# 대기오염 런던
# 현상 런던
# 생명 런던
# 시티 멕시코
# 스모그 멕시코
# 도시 멕시코
# 차량 멕시코
# 배기가스 멕시코
# 매연 멕시코
# 분진 멕시코
# 오존 멕시코
# 불량 멕시코
# 지수 멕시코
# 생활환경 멕시코
# 위험 멕시코
# 지표 멕시코
# 배 멕시코
# 초과 멕시코
# 스모그 서울
# 우려 서울
# 광화학 서울
# 스모그 서울
# 햇빛 서울
# 자외선 서울
# 차량 서울
# 오염 서울
# 물질 서울
# 맑은 서울
# 날 서울
# 안개 서울
# 것 서울
# 상태 서울
# 시정 서울
# 장애 서울
# 연 서울
# 발생 서울
# 오존층 보기
# 산성비 보기
# 황사 보기
# 각주 보기
# 출처 보기
# 및 보기
# 외부 보기
# 링크 보기
# 조윤승 보기
# 스모그 보기
# 건강 보기
# 피해 보기
# 런던 보기
# 스모그 보기
# 참사 보기
# 재 보기
# 조명 보기
# 환경 보기
# 위생 보기
# 학회 보기
# 고교생 인호
# 화학 인호
# 스페셜 인호
# 화사 인호
# 중국 인호
# 스모그 인호
# 피해 인호
# 스모그 베이징
# 잡기 베이징
# 국어사전 네이버
# 스모그 네이버
# 두산 네이버
# 백과사전 네이버
# 스모그 네이버
# 두산 네이버
# 백과사전 네이버
# 탈황 네이버
# 두산 네이버
# 백과사전 네이버
# 전기 네이버

# %%
degree=dict(G.degree)
nx.draw(G,font_family=font_name, font_size=9,node_size=[v * 10 for v in degree.values()],with_labels=True)
#plt.figure(figsize=(100,100))
plt.savefig("Graph.png", format="PNG")
plt.show()

# %%
degree1=dict(G1.degree)
nx.draw(G1,font_family=font_name, font_size=9,node_size=[v * 10 for v in degree1.values()],with_labels=True)
#plt.figure(figsize=(100,100))
plt.savefig("Graph1.png", format="PNG")
plt.show()

# %%
G3=nx.Graph()
G4=nx.Graph()



import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

import matplotlib.pyplot as plt
import string
# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='NanumGothic') # For Windows
print(plt.rcParams['font.family'])

text1=[]
text1=p_wiki1.text.split(".")

text2=[]
text2=p_wiki2.text.split(".")

i=0
for each_line in text1:
#for i in range (len(nouns1)):
    if each_line.find(nouns1[i])>0:
        nlpy3 = Twitter()
        nouns3 = nlpy3.nouns(each_line)
        print(nouns3)

i=0
for each_line in text2:
#for i in range (len(nouns1)):
    if each_line.find(nouns2[i])>0:
        nlpy4 = Twitter()
        nouns4 = nlpy4.nouns(each_line)
        print(nouns4)

i=0
for each_line in text1:
#for i in range (len(nouns1)):
    if each_line.find(nouns1[i])>0:
        nlpy3 = Twitter()
        nouns3 = nlpy3.nouns(each_line)
        G3.add_nodes_from(nouns3)
        for j in range (len(nouns3)):
            for l in range (len(nouns3)):
                if nouns3[j]!=nouns3[i]:
                    print(nouns3[j],nouns3[i])
                    G3.add_edges_from([(nouns3[j],nouns3[i])])
                    G3.add_edges_from([(nouns3[i],nouns3[j])])
                    break

i=0
for each_line in text2:
#for i in range (len(nouns1)):
    if each_line.find(nouns2[i])>0:
        nlpy4 = Twitter()
        nouns4 = nlpy4.nouns(each_line)
        G4.add_nodes_from(nouns4)
        for j in range (len(nouns4)):
            for l in range (len(nouns4)):
                if nouns4[j]!=nouns4[i]:
                    print(nouns4[j],nouns4[i])
                    G4.add_edges_from([(nouns4[j],nouns4[i])])
                    G4.add_edges_from([(nouns4[i],nouns4[j])])
                    break

degree3=dict(G3.degree)
nx.draw(G3,font_family=font_name, font_size=9,node_size=[v * 10 for v in degree.values()],with_labels=True)
#plt.figure(figsize=(100,100))
plt.savefig("Graph2.png", format="PNG")
plt.show()

degree4=dict(G4.degree)
nx.draw(G4,font_family=font_name, font_size=9,node_size=[v * 10 for v in degree1.values()],with_labels=True)
#plt.figure(figsize=(100,100))
plt.savefig("Graph3.png", format="PNG")
plt.show()
# Out:
# ['NanumGothic']
# ['초미세먼지', '미세먼지']
# ['미세먼지', '부유', '분진', '입자', '물질', '등', '불리', '명칭', '약간', '다른', '의미', '가지']
# ['미국', '펜실베이니아주', '도', '명', '사망', '대기오염', '사고', '약', '명의', '사망자', '발생', '런던', '스모그', '미세먼지', '인체', '영향', '대표', '사례']
# ['그', '이후', '미세먼지', '인체', '영향', '대한', '역학', '조사', '실시', '이하', '미세먼지', '입자', '취약', '집단', '질병', '발생', '률', '사망률', '등', '인체', '영향', '가능성', '것']
# ['형', '스모그', '광화학', '스모그', '로스앤젤레스', '스모그', '주로', '자동차', '배기가스', '속', '함유', '올레', '탄화수소', '질소', '산화물', '혼합물', '태양', '광선', '작용', '광화학', '반응', '것', '광화학', '스모그', '고도']
# ['런던', '스모그', '황화', '스모그', '주로', '공장', '및', '빌딩', '시설', '일반', '가정', '난방', '시설', '등', '배출', '아황산가스', '매연', '직접', '굴뚝', '오염', '물질', '발생', '스모그']
# ['피해', '상황', '배출', '연기', '안개', '스모그', '형성', '연기', '속', '아황산가스', '황산', '안개']
# ['광화학', '스모그', '경우', '인체', '영향', '주로', '눈']
# ['벤젠', '톨루엔', '등', '햇빛', '등', '반응', '광화학', '스모그', '장기간', '인체', '노', '출시', '백혈병', '암', '등', '유발', '수']
# ['런던', '스모그', '사건', '사건', '발생', '후', '첫', '주', '동안', '호흡', '장애', '질식', '등', '여명', '시민', '사망', '그', '후', '만성', '폐', '질환', '명', '추가', '사망', '총', '명', '동안', '대기오염', '현상', '생명']
# ['멕시코', '시티', '스모그', '도시', '차량', '배기가스', '매연', '분진', '오존', '불량', '지수', '생활환경', '위험', '지표', '배', '초과']
# ['서울', '스모그', '우려', '광화학', '스모그', '햇빛', '자외선', '차량', '오염', '물질', '맑은', '날', '안개', '것', '상태', '시정', '장애', '연', '발생']
# ['보기', '오존층', '산성비', '황사', '각주', '출처', '및', '외부', '링크', '조윤승', '스모그', '건강', '피해', '런던', '스모그', '참사', '재', '조명', '환경', '위생', '학회']
# ['인호', '고교생', '화학', '스페셜', '화사', '중국', '스모그', '피해']
# ['베이징', '스모그', '잡기']
# ['네이버', '국어사전', '스모그', '네이버', '두산', '백과사전', '스모그', '네이버', '두산', '백과사전', '탈황', '네이버', '두산', '백과사전', '전기']
# 미세먼지 초미세먼지
# 부유 미세먼지
# 분진 미세먼지
# 입자 미세먼지
# 물질 미세먼지
# 등 미세먼지
# 불리 미세먼지
# 명칭 미세먼지
# 약간 미세먼지
# 다른 미세먼지
# 의미 미세먼지
# 가지 미세먼지
# 펜실베이니아주 미국
# 도 미국
# 명 미국
# 사망 미국
# 대기오염 미국
# 사고 미국
# 약 미국
# 명의 미국
# 사망자 미국
# 발생 미국
# 런던 미국
# 스모그 미국
# 미세먼지 미국
# 인체 미국
# 영향 미국
# 대표 미국
# 사례 미국
# 이후 그
# 미세먼지 그
# 인체 그
# 영향 그
# 대한 그
# 역학 그
# 조사 그
# 실시 그
# 이하 그
# 미세먼지 그
# 입자 그
# 취약 그
# 집단 그
# 질병 그
# 발생 그
# 률 그
# 사망률 그
# 등 그
# 인체 그
# 영향 그
# 가능성 그
# 것 그
# 각 이후
# 국 이후
# 대기오염 이후
# 대책 이후
# 마련 이후
# 미세먼지 이후
# 인체 이후
# 환경 이후
# 영향 이후
# 위해 이후
# 대기오염 이후
# 기준 이후
# 마련 이후
# 입자 미세먼지
# 크기 미세먼지
# 이하 미세먼지
# 먼지 미세먼지
# 입자 미세먼지
# 크기 미세먼지
# 매우 미세먼지
# 구분 미세먼지
# 지름 미세먼지
# 지름 미세먼지
# 초미세먼지 것
# 원인 발생
# 미세먼지 발생
# 배출 발생
# 원인 발생
# 인위 발생
# 자연 발생
# 구분 발생
# 발생 인위
# 원인 인위
# 중국 인위
# 발 인위
# 미세먼지 인위
# 공장 인위
# 매연 인위
# 쓰레기 인위
# 소각 인위
# 항만 인위
# 지역 인위
# 가정 인위
# 생선 인위
# 그 인위
# 외 인위
# 것 인위
# 구울 인위
# 때 인위
# 등 인위
# 국가 발생
# 중국 발생
# 한국 발생
# 중국 발생
# 경우 발생
# 세계 발생
# 화석 발생
# 연료 발생
# 가장 발생
# 소비 발생
# 나라 발생
# 손 발생
# 베이징시 발생
# 톈진시 발생
# 칭다오시 발생
# 등 발생
# 동부 발생
# 지역 발생
# 고비 발생
# 사막 발생
# 인접 발생
# 곳도 발생
# 역시 발생
# 미세먼지 발생
# 범 발생
# 등 발생
# 아시아 발생
# 최대 발생
# 미세먼지 발생
# 원인 발생
# 공국 발생
# 손 발생
# 미세먼지 다만
# 주로 다만
# 건기 다만
# 겨울 다만
# 가장 다만
# 발생 다만
# 한반도 다만
# 북한 다만
# 전 다만
# 지역 다만
# 대한민국 다만
# 새만금 다만
# 이북 다만
# 지역 다만
# 중 다만
# 간지 다만
# 영향 다만
# 강원도 다만
# 영동 다만
# 지방 다만
# 경상북도 다만
# 북부 다만
# 동해안 다만
# 울릉도 다만
# 독도 다만
# 제외 다만
# 중부 다만
# 전 다만
# 지역 다만
# 남부 다만
# 일부 다만
# 지역 다만
# 발생 다만
# 경우 일본
# 미세먼지 일본
# 규슈 일본
# 이키 일본
# 섬 일본
# 쓰시마섬 일본
# 등지 일본
# 간 일본
# 적 일본
# 발생 일본
# 경우 일본
# 것 일본
# 중국 우리나라
# 미세먼지 우리나라
# 피해 우리나라
# 러시아 우리나라
# 러시아 우리나라
# 체적 우리나라
# 미세먼지 우리나라
# 발생량 우리나라
# 지역 우리나라
# 편차 우리나라
# 지역 연해주
# 경우 연해주
# 동풍 연해주
# 타고 연해주
# 미세먼지 연해주
# 유입 연해주
# 일 연해주
# 한반도 연해주
# 달리 연해주
# 덜 연해주
# 것 연해주
# 구성 미세먼지
# 성분 미세먼지
# 구성 미세먼지
# 성분 미세먼지
# 질산염 미세먼지
# 황산염 미세먼지
# 등 미세먼지
# 노인 질병
# 사망률 질병
# 증가 질병
# 국립 질병
# 환경과학 질병
# 인하대 질병
# 팀 질병
# 미세먼지 질병
# 사망률 질병
# 연구 질병
# 결과 질병
# 서울 질병
# 미세먼지 질병
# 농도 질병
# 당 질병
# 증가 질병
# 때 질병
# 살 질병
# 이상 질병
# 노인 질병
# 등 질병
# 대기오염 질병
# 집단 질병
# 사망률 질병
# 태아 임산부
# 이화여대 임산부
# 의대 임산부
# 하은 임산부
# 교수 임산부
# 팀 임산부
# 연구 임산부
# 결과 임산부
# 미세먼지 임산부
# 농도 임산부
# 저체중 임산부
# 출산 임산부
# 위험 임산부
# 부산 양산
# 병원 양산
# 산업의학 양산
# 전문의 양산
# 대기과학 양산
# 및 양산
# 지리 양산
# 정보 양산
# 시스템 양산
# 전문가 양산
# 공동 양산
# 연구 양산
# 진행 양산
# 결과 양산
# 미세먼지 양산
# 직경 양산
# 이하 양산
# 먼지 양산
# 농도 양산
# 저체중 양산
# 출산 양산
# 및 양산
# 사산 양산
# 기형 양산
# 발생 양산
# 관계 양산
# 것 양산
# 조사 양산
# 파크 카라칼
# 지역 카라칼
# 먼지 카라칼
# 호흡기 카라칼
# 질환 카라칼
# 상관관계 카라칼
# 조사 카라칼
# 건강 카라칼
# 위협 카라칼
# 미세먼지 카라칼
# 전체 카라칼
# 먼지 카라칼
# 가운데 카라칼
# 것 카라칼
# 이 카라칼
# 지역 카라칼
# 어린이 카라칼
# 폐활량 카라칼
# 등 카라칼
# 폐기 카라칼
# 능이 카라칼
# 유럽 카라칼
# 어린이 카라칼
# 현저 카라칼
# 것 카라칼
# 대학병원 미국
# 아동 미국
# 천 미국
# 백 미국
# 명 미국
# 조사 미국
# 연구 미국
# 미세먼지 미국
# 농도 미국
# 지역 미국
# 아이 미국
# 지역 미국
# 아이 미국
# 폐활량 미국
# 정상 미국
# 못 미국
# 폐 미국
# 기능 미국
# 장애 미국
# 를 미국
# 가능성 미국
# 것 미국
# 조사 미국
# 때문 사실
# 전문가 사실
# 미세먼지 사실
# 살인자 사실
# 사람 천식
# 폐포 천식
# 침투 천식
# 기관지 천식
# 폐 천식
# 미세먼지 천식
# 각종 천식
# 호흡기 천식
# 질환 천식
# 직접 천식
# 원인 천식
# 몸 천식
# 면역 천식
# 기능 천식
# 여성 또한
# 사망원인 또한
# 조리 또한
# 과정 또한
# 발생 또한
# 미세먼지 또한
# 사망 또한
# 환경 한국
# 정책 한국
# 평가 한국
# 연구원 한국
# 승헌 한국
# 박사 한국
# 팀 한국
# 결과 한국
# 미세먼지 한국
# 감축 한국
# 수도권 한국
# 관련 한국
# 질환 한국
# 사망자 한국
# 수가 한국
# 명 한국
# 심장 한국
# 및 한국
# 호흡기 한국
# 질환 한국
# 건수 한국
# 연간 한국
# 건 한국
# 수 한국
# 것 한국
# 전망 한국
# 심장 또
# 및 또
# 호흡기 또
# 계통 또
# 질환 또
# 관련 또
# 의료 또
# 비용 또
# 등 또
# 토대 또
# 미세먼지 또
# 감축 또
# 이익 또
# 계산 또
# 결과 또
# 연간 또
# 것 또
# 풀이 또
# 무연탄 두통
# 때 두통
# 신경계 두통
# 독성 두통
# 물질 두통
# 납 두통
# 비소 두통
# 아연 두통
# 등 두통
# 유해 두통
# 중금속 두통
# 농도 두통
# 미세먼지 두통
# 사람 두통
# 기침 두통
# 목 두통
# 피부 두통
# 트러블 두통
# 기도 두통
# 미세먼지 대부분
# 치명 대부분
# 중 대부분
# 황산 대부분
# 이온 대부분
# 질산 대부분
# 이온 대부분
# 등 대부분
# 황사 대부분
# 속 대부분
# 먼지 대부분
# 흡착 대부분
# 산화물 대부분
# 호흡 대부분
# 폐 대부분
# 모공 아토피
# 더 아토피
# 초미세먼지 아토피
# 모공 아토피
# 침투 아토피
# 등 아토피
# 피부염 아토피
# 원인 아토피
# 때문 아토피
# 여드름 아토피
# 사람 아토피
# 역시 아토피
# 황사 아토피
# 예보 아토피
# 야외 아토피
# 활동 아토피
# 자제 아토피
# 것 아토피
# 저항 인슐린
# 대기오염 인슐린
# 미세먼지 인슐린
# 주성분 인슐린
# 노년 인슐린
# 여성 인슐린
# 저항 인슐린
# 연구 인슐린
# 결과 인슐린
# 대책 예방
# 사전 예방
# 미세먼지 예방
# 농도 예방
# 확인 예방
# 후 예방
# 농도 예방
# 활동 예방
# 범위 예방
# 정 예방
# 로부터 미세먼지
# 보호 미세먼지
# 수 미세먼지
# 가장 미세먼지
# 보편 미세먼지
# 방법 미세먼지
# 차단 미세먼지
# 마스크 미세먼지
# 착용 미세먼지
# 것 미세먼지
# 차단 미세먼지
# 성능 미세먼지
# 마스크 미세먼지
# 제품 미세먼지
# 포장 미세먼지
# 의약외품 미세먼지
# 문자 미세먼지
# 등 미세먼지
# 표시 미세먼지
# 링크 외부
# 위키미디어 외부
# 공용 외부
# 미세먼지 외부
# 관련 외부
# 미디어 외부
# 분류 외부
# 스모그 형태
# 바람 형태
# 기온역전 형태
# 기상 형태
# 상태 형태
# 발생 형태
# 기상 기온역전
# 조건 기온역전
# 스모그 기온역전
# 높이 기온역전
# 것 기온역전
# 도시 기온역전
# 근처 기온역전
# 산맥 기온역전
# 스모그 기온역전
# 데 기온역전
# 한몫 기온역전
# 피해 스모그
# 미국 스모그
# 펜실베이니아주 스모그
# 도 스모그
# 발생 스모그
# 광화학 스모그
# 여 스모그
# 명 스모그
# 사망 스모그
# 명 스모그
# 가량 스모그
# 병 스모그
# 런던 영국
# 발생 영국
# 스모그 영국
# 집중 영국
# 현상 영국
# 동안 영국
# 약 영국
# 명 영국
# 사망 영국
# 식물 스모그
# 죽 스모그
# 건축 스모그
# 재의 스모그
# 부식 스모그
# 진행 스모그
# 스모그 서울
# 주로 서울
# 미세먼지 서울
# 오염 서울
# 대기 서울
# 습도 서울
# 바람 서울
# 날 서울
# 발생 서울
# 발생 스모그
# 하늘 스모그
# 볼 스모그
# 수 스모그
# 거리 스모그
# 대기오염 스모그
# 봄 겨울
# 난방 겨울
# 산업 겨울
# 연료 겨울
# 연소 겨울
# 중 겨울
# 황산 겨울
# 화물 겨울
# 먼지 겨울
# 때문 겨울
# 스모그 겨울
# 발생 겨울
# 여름 겨울
# 자동차 겨울
# 질소 겨울
# 산화물 겨울
# 탄화수소 겨울
# 광화학 겨울
# 반응 겨울
# 스모그 겨울
# 발생 겨울
# 주요 스모그
# 원인 스모그
# 미세먼지 스모그
# 연료 스모그
# 연소 스모그
# 과정 스모그
# 발생 스모그
# 성분 스모그
# 자동차 스모그
# 발생 스모그
# 성분 스모그
# 스모그 런던
# 황화 런던
# 스모그 런던
# 화석연료 런던
# 이산화황 런던
# 일산화탄소 런던
# 때문 런던
# 스모그 형
# 광화학 형
# 스모그 형
# 자동차 형
# 배기 형
# 가스 형
# 질소 형
# 산화물 형
# 스모그 화산
# 자연 화산
# 스모그 화산
# 폭발 화산
# 분출 화산
# 이산화황 화산
# 때문 화산
# 스모그 혼합형
# 서울 혼합형
# 스모그 혼합형
# 런던 혼합형
# 스모그 혼합형
# 형 혼합형
# 스모그 혼합형
# 현상 혼합형
# 스모그 종류
# 크게 종류
# 형 종류
# 스모그 종류
# 런던 종류
# 스모그 종류
# 스모그 원래
# 석탄 원래
# 연소 원래
# 데 원래
# 여러 원래
# 가지 원래
# 결과물 원래
# 안개 원래
# 회색 원래
# 안개 원래
# 식 원래
# 발생 원래
# 것 원래
# 달리 원래
# 광화학 원래
# 스모그 원래
# 자동차 원래
# 배기가스 원래
# 석유 원래
# 연료 원래
# 연소 원래
# 후 원래
# 이후 원래
# 빛 원래
# 화학반응 원래
# 과정 원래
# 통해 원래
# 생물 원래
# 화합물 원래
# 황 원래
# 갈색 원래
# 안개 원래
# 스모그 광화학
# 미국 광화학
# 로스엔젤레스 광화학
# 처음 광화학
# 발생 광화학
# 확인 광화학
# 때문 광화학
# 과거 광화학
# 스모그 광화학
# 런던 광화학
# 스모그 광화학
# 스모그 광화학
# 로스앤젤레스 광화학
# 스모그 광화학
# 기도 광화학
# 스모그 형
# 광화학 형
# 스모그 형
# 로스앤젤레스 형
# 스모그 형
# 주로 형
# 자동차 형
# 배기가스 형
# 속 형
# 함유 형
# 올레 형
# 탄화수소 형
# 질소 형
# 산화물 형
# 혼합물 형
# 태양 형
# 광선 형
# 작용 형
# 광화학 형
# 반응 형
# 것 형
# 광화학 형
# 스모그 형
# 고도 형
# 스모그 런던
# 황화 런던
# 스모그 런던
# 주로 런던
# 공장 런던
# 및 런던
# 빌딩 런던
# 시설 런던
# 일반 런던
# 가정 런던
# 난방 런던
# 시설 런던
# 등 런던
# 배출 런던
# 아황산가스 런던
# 매연 런던
# 직접 런던
# 굴뚝 런던
# 오염 런던
# 물질 런던
# 발생 런던
# 스모그 런던
# 상황 피해
# 배출 피해
# 연기 피해
# 안개 피해
# 스모그 피해
# 형성 피해
# 연기 피해
# 속 피해
# 아황산가스 피해
# 황산 피해
# 안개 피해
# 스모그 광화학
# 경우 광화학
# 인체 광화학
# 영향 광화학
# 주로 광화학
# 눈 광화학
# 톨루엔 벤젠
# 등 벤젠
# 햇빛 벤젠
# 등 벤젠
# 반응 벤젠
# 광화학 벤젠
# 스모그 벤젠
# 장기간 벤젠
# 인체 벤젠
# 노 벤젠
# 출시 벤젠
# 백혈병 벤젠
# 암 벤젠
# 등 벤젠
# 유발 벤젠
# 수 벤젠
# 스모그 런던
# 사건 런던
# 사건 런던
# 발생 런던
# 후 런던
# 첫 런던
# 주 런던
# 동안 런던
# 호흡 런던
# 장애 런던
# 질식 런던
# 등 런던
# 여명 런던
# 시민 런던
# 사망 런던
# 그 런던
# 후 런던
# 만성 런던
# 폐 런던
# 질환 런던
# 명 런던
# 추가 런던
# 사망 런던
# 총 런던
# 명 런던
# 동안 런던
# 대기오염 런던
# 현상 런던
# 생명 런던
# 시티 멕시코
# 스모그 멕시코
# 도시 멕시코
# 차량 멕시코
# 배기가스 멕시코
# 매연 멕시코
# 분진 멕시코
# 오존 멕시코
# 불량 멕시코
# 지수 멕시코
# 생활환경 멕시코
# 위험 멕시코
# 지표 멕시코
# 배 멕시코
# 초과 멕시코
# 스모그 서울
# 우려 서울
# 광화학 서울
# 스모그 서울
# 햇빛 서울
# 자외선 서울
# 차량 서울
# 오염 서울
# 물질 서울
# 맑은 서울
# 날 서울
# 안개 서울
# 것 서울
# 상태 서울
# 시정 서울
# 장애 서울
# 연 서울
# 발생 서울
# 오존층 보기
# 산성비 보기
# 황사 보기
# 각주 보기
# 출처 보기
# 및 보기
# 외부 보기
# 링크 보기
# 조윤승 보기
# 스모그 보기
# 건강 보기
# 피해 보기
# 런던 보기
# 스모그 보기
# 참사 보기
# 재 보기
# 조명 보기
# 환경 보기
# 위생 보기
# 학회 보기
# 고교생 인호
# 화학 인호
# 스페셜 인호
# 화사 인호
# 중국 인호
# 스모그 인호
# 피해 인호
# 스모그 베이징
# 잡기 베이징
# 국어사전 네이버
# 스모그 네이버
# 두산 네이버
# 백과사전 네이버
# 스모그 네이버
# 두산 네이버
# 백과사전 네이버
# 탈황 네이버
# 두산 네이버
# 백과사전 네이버
# 전기 네이버

# %%
data=[]
for n in G3:
    data.append([n,degree3[n]])
#    print ("%s %f, %f "%(n, degree[n])
df=pd.DataFrame(data)
df.to_csv("./result.csv",encoding='ms949')

# %%
data=[]
for n in G4:
    data.append([n,degree4[n]])
#    print ("%s %f, %f "%(n, degree[n])
df=pd.DataFrame(data)
df.to_csv("./result1.csv",encoding='ms949')

# %%
mean_degree3=sum(degree3.values())/len(G3.nodes)

# %%
mean_degree4=sum(degree4.values())/len(G4.nodes)

# %%
print("Mean_degree")
print(mean_degree3)
print("Density")
print(nx.density(G3))
print("Mean_degree")
print(mean_degree4)
print("Density")
print(nx.density(G4))
# Out:
# Mean_degree
# 2.7731629392971247
# Density
# 0.00888834275415745
# Mean_degree
# 2.77511961722488
# Density
# 0.013341921236658078

# %%
degree_sequence = sorted([d for n, d in G3.degree()], reverse=True)  # degree sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
plt.bar(deg, cnt, width=0.80, color="b")
# Out:
# <BarContainer object of 25 artists>
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
degree_sequence = sorted([d for n, d in G4.degree()], reverse=True)  # degree sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
plt.bar(deg, cnt, width=0.80, color="b")
# Out:
# <BarContainer object of 18 artists>

# %%
print(nx.clustering(G3))
# Out:
018518518518518517, '석탄': 0, '여러': 0, '가지': 0, '결과물': 0, '안개': 0, '회색': 0, '식': 0, '달리': 0, '배기가스': 0, '석유': 0, '후': 0, '이후': 0, '빛': 0, '화학반응': 0, '통해': 0, '생물': 0, '화합물': 0, '황': 0, '갈색': 0, '로스엔젤레스': 0, '처음': 0, '확인': 0, '과거': 0, '로스앤젤레스': 1.0, '기도': 0, '속': 0, '함유': 0, '올레': 0, '혼합물': 0, '태양': 0, '광선': 0, '작용': 0, '고도': 0, '공장': 0, '및': 1.0, '빌딩': 0, '시설': 0, '일반': 0, '가정': 0, '등': 0, '배출': 0, '아황산가스': 0, '매연': 0, '직접': 0, '굴뚝': 0, '물질': 0, '상황': 0, '연기': 0, '형성': 0, '경우': 0, '인체': 1.0, '영향': 0, '눈': 0, '벤젠': 0.03296703296703297, '톨루엔': 0, '햇빛': 0, '장기간': 0, '노': 0, '출시': 0, '백혈병': 0, '암': 0, '유발': 0, '사건': 0, '첫': 0, '주': 0, '호흡': 0, '장애': 0, '질식': 0, '여명': 0, '시민': 0, '그': 0, '만성': 0, '폐': 0, '질환': 0, '추가': 0, '총': 0, '생명': 0, '멕시코': 0, '시티': 0, '차량': 0, '분진': 0, '오존': 0, '불량': 0, '지수': 0, '생활환경': 0, '위험': 0, '지표': 0, '배': 0, '초과': 0, '우려': 0, '자외선': 0, '맑은': 0, '시정': 0, '연': 0, '보기': 0.017543859649122806, '오존층': 0, '산성비': 0, '황사': 0, '각주': 0, '출처': 0, '외부': 0, '링크': 0, '조윤승': 0, '건강': 0, '참사': 0, '재': 0, '조명': 0, '환경': 0, '위생': 0, '학회': 0, '인호': 0.047619047619047616, '고교생': 0, '화학': 0, '스페셜': 0, '화사': 0, '중국': 0, '베이징': 0, '잡기': 0, '네이버': 0, '국어사전': 0, '두산': 0, '백과사전': 0, '탈황': 0, '전기': 0}

# %%
print(nx.laplacian_matrix(G3))
# Out:
#   (0, 0)	3
#   (0, 1)	-1
#   (0, 43)	-1
#   (0, 275)	-1
#   (1, 0)	-1
#   (1, 1)	61
#   (1, 2)	-1
#   (1, 3)	-1
#   (1, 4)	-1
#   (1, 5)	-1
#   (1, 6)	-1
#   (1, 7)	-1
#   (1, 8)	-1
#   (1, 9)	-1
#   (1, 10)	-1
#   (1, 11)	-1
#   (1, 12)	-1
#   (1, 13)	-1
#   (1, 23)	-1
#   (1, 30)	-1
#   (1, 31)	-1
#   (1, 36)	-1
#   (1, 39)	-1
#   (1, 43)	-1
#   (1, 51)	-1
#   :	:
#   (303, 303)	1
#   (304, 1)	-1
#   (304, 304)	1
#   (305, 1)	-1
#   (305, 305)	1
#   (306, 1)	-1
#   (306, 306)	1
#   (307, 1)	-1
#   (307, 235)	-1
#   (307, 307)	7
#   (307, 308)	-1
#   (307, 309)	-1
#   (307, 310)	-1
#   (307, 311)	-1
#   (307, 312)	-1
#   (308, 307)	-1
#   (308, 308)	1
#   (309, 307)	-1
#   (309, 309)	1
#   (310, 307)	-1
#   (310, 310)	1
#   (311, 307)	-1
  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#   1.00000000e+00+0.00000000e+00j]

# %%
unique_nums3 = set(e3)
sorted_nums3 = sorted(unique_nums3, reverse=False)
print(sorted_nums3[0])
print(sorted_nums3[1])
# Out:
# (-5.604596783415419e-16+0j)
# (0.09083149214368645+0j)

# %%
unique_nums4 = set(e4)
sorted_nums4 = sorted(unique_nums4, reverse=False)
print(sorted_nums4[0])
print(sorted_nums4[1])
# Out:
# (-2.220446049250313e-16+0j)
# (0.08457217082331435+0j)

# %%
print(numpy.finfo(float).eps)
# Out:
# 2.220446049250313e-16

# %%
degree = nx.degree_centrality(G)
between = nx.betweenness_centrality(G)
close = nx.closeness_centrality(G)
eigen = nx.eigenvector_centrality(G)
data=[]
## print the multiple centrality metrics to a single line for each node:
for n in G:
    data.append([n,degree[n],between[n],close[n],eigen[n]])
    print ("%s %f, %f, %f, %f"%(n, degree[n], between[n], close[n], eigen[n]))
df=pd.DataFrame(data)
df.to_csv("./centrality1.csv",encoding='ms949')
# Out:
# 초미세먼지 0.019231, 0.004017, 0.364061, 0.075073
# 미세먼지 0.391026, 0.553208, 0.547368, 0.505015
# 부유 0.006410, 0.000000, 0.354143, 0.049232
# 분진 0.006410, 0.000000, 0.354143, 0.049232
# 입자 0.012821, 0.000000, 0.359033, 0.069549
# 물질 0.012821, 0.000000, 0.361111, 0.058800
# 등 0.064103, 0.050601, 0.421622, 0.180082
# 불리 0.006410, 0.000000, 0.354143, 0.049232
# 명칭 0.006410, 0.000000, 0.354143, 0.049232
# 약간 0.006410, 0.000000, 0.354143, 0.049232
# 다른 0.006410, 0.000000, 0.354143, 0.049232
# 의미 0.006410, 0.000000, 0.354143, 0.049232
# 가지 0.006410, 0.000000, 0.354143, 0.049232
# 미국 0.224359, 0.146420, 0.398977, 0.201772
# 펜실베이니아주 0.006410, 0.000000, 0.285453, 0.019671
# 도 0.006410, 0.000000, 0.285453, 0.019671
# 명 0.012821, 0.001573, 0.297143, 0.035850
# 사망 0.012821, 0.000778, 0.288089, 0.027915
# 대기오염 0.025641, 0.004367, 0.302913, 0.049287
# 사고 0.006410, 0.000000, 0.285453, 0.019671
# 약 0.006410, 0.000000, 0.285453, 0.019671
# 명의 0.006410, 0.000000, 0.285453, 0.019671
# 사망자 0.012821, 0.001573, 0.297143, 0.035850
# 발생 0.243590, 0.189033, 0.452174, 0.294572
# 런던 0.006410, 0.000000, 0.285453, 0.019671
# 스모그 0.006410, 0.000000, 0.285453, 0.019671
# 인체 0.019231, 0.001387, 0.301741, 0.049113
# 영향 0.025641, 0.007672, 0.316751, 0.062233
# 대표 0.006410, 0.000000, 0.285453, 0.019671
# 사례 0.006410, 0.000000, 0.285453, 0.019671
# 그 0.128205, 0.055822, 0.397452, 0.208396
# 이후 0.076923, 0.039763, 0.366627, 0.093603
# 대한 0.006410, 0.000000, 0.284672, 0.020317
# 역학 0.006410, 0.000000, 0.284672, 0.020317
# 조사 0.025641, 0.005969, 0.320988, 0.071118
# 실시 0.006410, 0.000000, 0.284672, 0.020317
# 이하 0.019231, 0.000614, 0.368359, 0.086873
# 취약 0.006410, 0.000000, 0.284672, 0.020317
# 집단 0.012821, 0.000000, 0.288889, 0.033863
# 질병 0.128205, 0.069242, 0.376812, 0.138948
# %%
degree = nx.degree_centrality(G1)
between = nx.betweenness_centrality(G1)
close = nx.closeness_centrality(G1)
eigen = nx.eigenvector_centrality(G1)
data=[]
## print the multiple centrality metrics to a single line for each node:
for n in G1:
    data.append([n,degree[n],between[n],close[n],eigen[n]])
    print ("%s %f, %f, %f, %f"%(n, degree[n], between[n], close[n], eigen[n]))
df=pd.DataFrame(data)
df.to_csv("./centrality2.csv",encoding='ms949')
# Out:
# 형태 0.057692, 0.011307, 0.371429, 0.086108
# 스모그 0.451923, 0.576123, 0.563686, 0.468687
# 바람 0.019231, 0.000261, 0.289291, 0.029063
# 기온역전 0.105769, 0.060200, 0.374775, 0.075937
# 기상 0.019231, 0.000000, 0.274406, 0.017017
# 상태 0.019231, 0.000261, 0.289291, 0.029063
# 발생 0.076923, 0.025640, 0.438819, 0.200171
# 조건 0.009615, 0.000000, 0.272966, 0.007975
# 높이 0.009615, 0.000000, 0.272966, 0.007975
# 것 0.038462, 0.012840, 0.326531, 0.067368
# 도시 0.019231, 0.002126, 0.283379, 0.015488
# 근처 0.009615, 0.000000, 0.272966, 0.007975
# 산맥 0.009615, 0.000000, 0.272966, 0.007975
# 데 0.019231, 0.002075, 0.295455, 0.028543
# 한몫 0.009615, 0.000000, 0.272966, 0.007975
# 피해 0.105769, 0.046579, 0.387337, 0.093809
# 미국 0.019231, 0.000000, 0.369449, 0.076554
# 펜실베이니아주 0.009615, 0.000000, 0.361111, 0.049221
# 도 0.009615, 0.000000, 0.361111, 0.049221
# 광화학 0.201923, 0.136560, 0.465324, 0.260275
# 여 0.009615, 0.000000, 0.361111, 0.049221
# 명 0.028846, 0.000000, 0.390244, 0.104884
# 사망 0.028846, 0.000000, 0.390244, 0.104884
# 가량 0.009615, 0.000000, 0.361111, 0.049221
# 병 0.009615, 0.000000, 0.361111, 0.049221
# 영국 0.086538, 0.022858, 0.394687, 0.148777
# 런던 0.471154, 0.296721, 0.451193, 0.381277
# 집중 0.009615, 0.000000, 0.283379, 0.015624
# 현상 0.028846, 0.000046, 0.328594, 0.069885
# 동안 0.019231, 0.000000, 0.312782, 0.055663
# 약 0.009615, 0.000000, 0.283379, 0.015624
# 식물 0.009615, 0.000000, 0.361111, 0.049221
# 죽 0.009615, 0.000000, 0.361111, 0.049221
# 건축 0.009615, 0.000000, 0.361111, 0.049221
# 재의 0.009615, 0.000000, 0.361111, 0.049221
# 부식 0.009615, 0.000000, 0.361111, 0.049221
# 진행 0.009615, 0.000000, 0.361111, 0.049221
# 서울 0.221154, 0.114341, 0.396947, 0.190639
# 주로 0.038462, 0.008096, 0.372760, 0.106197
# 미세먼지 0.019231, 0.000000, 0.373429, 0.069241
# 오염 0.019231, 0.002407, 0.326531, 0.060059
# 대기 0.009615, 0.000000, 0.284542, 0.020020
# 습도 0.009615, 0.000000, 0.284542, 0.020020
# 날 0.009615, 0.000000, 0.284542, 0.020020
# 하늘 0.009615, 0.000000, 0.361111, 0.049221
# 볼 0.009615, 0.000000, 0.361111, 0.049221
